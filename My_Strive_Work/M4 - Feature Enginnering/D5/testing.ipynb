# %%
import time
from IPython.display import clear_output
import numpy    as np
import pandas   as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import sklearn
from sklearn import pipeline  ,ensemble 
from sklearn.pipeline import Pipeline 
from sklearn import impute
from sklearn import compose
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, balanced_accuracy_score, plot_confusion_matrix,roc_auc_score
from sklearn import set_config
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import Normalizer,PowerTransformer,QuantileTransformer, RobustScaler,StandardScaler,LabelEncoder, OneHotEncoder,OrdinalEncoder
from sklearn.tree          import DecisionTreeClassifier
from sklearn.linear_model  import LogisticRegression    
from sklearn.experimental  import enable_hist_gradient_boosting # Necesary for HistGradientBoostingClassifier
from xgboost               import XGBClassifier
from lightgbm              import LGBMClassifier
from catboost              import CatBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
set_config(display='diagram') # Useful for display the pipeline
print("Pandas  ", pd.__version__)
print("Sklearn ", sklearn.__version__) # Try to use 0.24
# Out:
# Pandas   1.2.4
# Sklearn  0.24.2

# %%
df = pd.read_csv('heart.csv')
df_train=df.iloc[:250,:]
df_test=df.iloc[250:,:].drop('target',axis=1)

# %%
df_train['target'].value_counts().plot(kind='bar', title='Count (target)');

# %%
print(f"Train data Describe \n{df_train.describe()}\n")
# Out:
# Train data Describe
#               age         sex          cp    trestbps        chol         fbs  \
# count  250.000000  250.000000  250.000000  250.000000  250.000000  250.000000
# mean    54.080000    0.660000    1.072000  131.392000  247.524000    0.140000
# std      9.381773    0.474659    1.015352   17.399116   52.623096    0.347683
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.000000    0.000000    0.000000  120.000000  211.250000    0.000000
# 50%     54.500000    1.000000    1.000000  130.000000  243.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#          restecg     thalach       exang     oldpeak       slope          ca  \
# count  250.00000  250.000000  250.000000  250.000000  250.000000  250.000000
# mean     0.50400  152.472000    0.276000    0.944800    1.436000    0.628000
# std      0.50894   21.852766    0.447914    1.108054    0.625676    0.986666
# min      0.00000   88.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.00000  140.250000    0.000000    0.000000    1.000000    0.000000
# 50%      0.50000  156.000000    0.000000    0.600000    2.000000    0.000000
# 75%      1.00000  169.000000    1.000000    1.500000    2.000000    1.000000
# max      2.00000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  250.000000  250.000000
# mean     2.308000    0.660000
# std      0.578337    0.474659
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
columns = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
       'exang', 'oldpeak', 'slope', 'ca', 'thal',]

plt.figure(figsize=(16, 14))
sns.set(font_scale= 1.2)
sns.set_style('ticks')

for i, feature in enumerate(columns):
    plt.subplot(4, 4, i+1)
    sns.violinplot(x="target",y=feature,data=df_train)
    
sns.despine()

# %%
df_train['chol*age']=df_train['chol']*df_train['age']
df_train['trestbps*cp']=df_train['trestbps']*df_train['cp']
df_train['trestbps*age']=df_train['trestbps']*df_train['age']

# %%
columns = ['age', 'cp', 'trestbps', 'chol', 'chol*age','trestbps*cp','trestbps*age']

plt.figure(figsize=(16, 14))
sns.set(font_scale= 1.2)
sns.set_style('ticks')

for i, feature in enumerate(columns):
    plt.subplot(4, 4, i+1)
    sns.violinplot(x="target",y=feature,data=df_train)
    
sns.despine()

# %%
sns.catplot(x='sex', kind='count', data=df_train)
plt.show()
plt.close()

# %%
plt.figure(figsize=(16, 6))

heatmap = sns.heatmap(df_train.corr(), vmin=-1, vmax=1, annot=True)
heatmap
# Out:
# <AxesSubplot:>

# %%
num_vars=['age',  'trestbps', 'chol', 'thalach','oldpeak', 'chol*age', 'trestbps*cp', 'trestbps*age']
cat_vars=[ 'sex', 'cp', 'fbs', 'restecg','exang',  'slope', 'ca', 'thal' ]

# %%
from sklearn.preprocessing import scale
print(df.info())
# Centering and Scaling Model Features
    # Separating Features and Labels
data_features = df.drop('target', axis=1)
data_labels = df.target
    # Scaling Features
data_features_scaled = scale(data_features)

# Features/Label in numpy arrays
features = data_features_scaled
label = data_labels.to_numpy()
# Model/Hold-out sets
model_features, holdout_features, model_label, holdout_label = \
    train_test_split(features, label, test_size=0.2, random_state=57, stratify=label)
# Test/Train sets from Model set
train_features, test_features, train_label, test_label = \
    train_test_split(model_features, model_label, test_size=0.2, random_state=14, stratify=model_label)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB
# None

# %%
neighbors = np.arange(1, 25, step=1)
train_accuracy = np.empty(len(neighbors))
test_accuracy = np.empty(len(neighbors))
# Iterating Hyperparamater Candidates and Recording Performance
for i, k in enumerate(neighbors):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(train_features, train_label)
    train_accuracy[i] = knn.score(train_features, train_label)
    test_accuracy[i] = knn.score(test_features, test_label)
# Visualize Performance of Hyperparamaters
plt.title('k,NN: Varying Number of Neighbors')
plt.plot(neighbors, test_accuracy, label='Testing Accuracy', color='red', marker='o')
plt.plot(neighbors, train_accuracy, label='Training Accuracy', linestyle='--', color='grey')
plt.xticks(neighbors)
plt.legend()
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
plt.show()
plt.close
# Out:
# <function matplotlib.pyplot.close(fig=None)>

# %%
from sklearn.metrics import classification_report
# Fitting and Scoring the model
knn = KNeighborsClassifier(n_neighbors=41)
knn.fit(model_features, model_label)
knn_model_score = knn.score(model_features, model_label)
knn_holdout_score = knn.score(holdout_features, holdout_label)
knn_holdout_predict = knn.predict(holdout_features)
print('INITIAL MODEL PERFORMANCE')
print('kNN Score on Training Data: {}%'.format((knn_model_score*100).round(2)))
print('kNN Score on Hold-Out Data: {}%'.format((knn_holdout_score*100).round(2)))
print('kNN Classification Report:')
print(classification_report(holdout_label, knn_holdout_predict))
print('')
# Out:
# INITIAL MODEL PERFORMANCE
# kNN Score on Training Data: 82.64%
# kNN Score on Hold-Out Data: 88.52%
# kNN Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.82      0.87        28
#            1       0.86      0.94      0.90        33
#
#     accuracy                           0.89        61
#    macro avg       0.89      0.88      0.88        61
# weighted avg       0.89      0.89      0.88        61

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
# Tuning for optimal hyperparameter 'k' (number of neighbors) with GridSearchCV
param_grid = {'n_neighbors': np.arange(1, 100, step=1)}
knn = KNeighborsClassifier()
knn_grid_cv = GridSearchCV(knn, param_grid, cv=2)
knn_grid_cv.fit(model_features, model_label)
optimal_k = knn_grid_cv.best_params_['n_neighbors']
optimal_score = knn_grid_cv.best_score_
# Testing the model on unseen data
knn_tuned = KNeighborsClassifier(n_neighbors=optimal_k)
knn_tuned.fit(model_features, model_label)
accuracy = knn_tuned.score(holdout_features, holdout_label)
knn_tuned_predict = knn_tuned.predict(holdout_features)
print('TUNING PERFORMANCE')
print('Optimal Value of Hyperparameter: {}'.format(optimal_k))
print('kNN Score on Training Data: {}%'.format((optimal_score * 100).round(2)))
print('kNN Score on Hold-Out Data: {}%'.format((accuracy * 100).round(2)))
print('kNN Classifciation Report:')
print(classification_report(holdout_label, knn_tuned_predict))
# Out:
# TUNING PERFORMANCE
# Optimal Value of Hyperparameter: 14
# kNN Score on Training Data: 82.64%
# kNN Score on Hold-Out Data: 85.25%
# kNN Classifciation Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.82      0.84        28
#            1       0.85      0.88      0.87        33
#
#     accuracy                           0.85        61
#    macro avg       0.85      0.85      0.85        61
# weighted avg       0.85      0.85      0.85        61

# %% [markdown]
# # Pipeline  for preprocess

# %%
num_4_Models = pipeline.Pipeline(steps=[
    ('scalar',PowerTransformer()),
    ('Normalizer',Normalizer())
])
cat_4_Models = pipeline.Pipeline(steps=[
  ('onehot', OneHotEncoder( handle_unknown='ignore'))
])

preprocessor = compose.ColumnTransformer(transformers=[
    ('num', num_4_Models, num_vars),
    ('cat', cat_4_Models, cat_vars),
], remainder='drop') # Drop other vars not specified in num_vars or cat_vars
preprocessor
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('scalar', PowerTransformer()),
#                                                  ('Normalizer', Normalizer())]),
#                                  ['age', 'trestbps', 'chol', 'thalach',
#                                   'oldpeak', 'chol*age', 'trestbps*cp',
#                                   'trestbps*age']),
#                                 ('cat',
#                                  Pipeline(steps=[('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  ['sex', 'cp', 'fbs', 'restecg', 'exang',
#                                   'slope', 'ca', 'thal'])])

# %% [markdown]
# # Models

# %%
from sklearn.svm import SVC
SVC_clf=SVC()
SVC_clf.fit(X_train,Y_train)
SVC_score=SVC_clf.score(X_test,Y_test)
SVC_Y_pred=SVC_clf.predict(X_test)
#print(SVC_score)
evaluation(Y_test,SVC_Y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-a6f23fc42e93> in <module>
#       1 from sklearn.svm import SVC
#       2 SVC_clf=SVC()
# ----> 3 SVC_clf.fit(X_train,Y_train)
#       4 SVC_score=SVC_clf.score(X_test,Y_test)
#       5 SVC_Y_pred=SVC_clf.predict(X_test)
#
# NameError: name 'X_train' is not defined

# %%
classifier_models = {
"DecisionTreeClassifier": DecisionTreeClassifier(),
'KNeighborsClassifier':KNeighborsClassifier(),
'LogisticRegression':LogisticRegression(),
"RandomForestClassifier":ensemble.RandomForestClassifier(),
"AdaBoostClassifier":ensemble.AdaBoostClassifier(),
"GradientBoostingClassifier":ensemble.GradientBoostingClassifier(),
"XGBClassifier":XGBClassifier(),
"LGBMClassifier":LGBMClassifier(),
"CatBoostClassifier":CatBoostClassifier(),
}
# make pipline with  preprocessing 
classifier_models = {name: pipeline.make_pipeline(preprocessor, model) for name, model in classifier_models.items()}
classifier_models["GradientBoostingClassifier"]
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scalar',
#                                                                    PowerTransformer()),
#                                                                   ('Normalizer',
#                                                                    Normalizer())]),
#                                                   ['age', 'trestbps', 'chol',
#                                                    'thalach', 'oldpeak',
#                                                    'chol*age', 'trestbps*cp',
#                                                    'trestbps*age']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['sex', 'cp', 'fbs',
#                                                    'restecg', 'exang', 'slope',
#                                                    'ca', 'thal'])])),
#                 ('gradientboostingclassifier', GradientBoostingClassifier())])

# %%
x=df_train.drop('target',axis=1)
y=df_train['target']
x_train, x_val, y_train, y_val = train_test_split(x, y,test_size=0.2,stratify = y,random_state=10 )
results = pd.DataFrame({'Model': [], 'Accuracy': [], 'Bal Acc.': [],'Time': []})
for model_name, model in classifier_models.items():
    start_time = time.time()
    model.fit(x_train, y_train)
    total_time = time.time() - start_time
    valid_pred = model.predict(x_val)
    results = results.append({"Model":    model_name,
                              "Accuracy": accuracy_score(y_val, valid_pred)*100,
                              "Bal Acc.": balanced_accuracy_score(y_val, valid_pred)*100,
                    
                              "Time":     total_time},
                              ignore_index=True)
results_ord = results.sort_values(by=['Accuracy'], ascending=False, ignore_index=True)
results_ord.index += 1 
results_ord.style.bar(subset=['Accuracy', 'Bal Acc.'], vmin=0, vmax=100, color='#5fba7d')
# Out:
# 1:	learn: 0.6850520	total: 60.3ms	remaining: 30.1s
# 2:	learn: 0.6802955	total: 67.4ms	remaining: 22.4s
# 3:	learn: 0.6759886	total: 71.7ms	remaining: 17.9s
# 4:	learn: 0.6721302	total: 75.9ms	remaining: 15.1s
# 5:	learn: 0.6688504	total: 83.4ms	remaining: 13.8s
# 6:	learn: 0.6649154	total: 87.3ms	remaining: 12.4s
# 7:	learn: 0.6609627	total: 93.4ms	remaining: 11.6s
# 8:	learn: 0.6564128	total: 96.9ms	remaining: 10.7s
# 9:	learn: 0.6535639	total: 98ms	remaining: 9.7s
# 10:	learn: 0.6496695	total: 100ms	remaining: 9.01s
# 11:	learn: 0.6447590	total: 103ms	remaining: 8.51s
# 12:	learn: 0.6402398	total: 106ms	remaining: 8.03s
# 13:	learn: 0.6355929	total: 108ms	remaining: 7.6s
# 14:	learn: 0.6310126	total: 111ms	remaining: 7.32s
# 15:	learn: 0.6268372	total: 114ms	remaining: 7s
# 16:	learn: 0.6226509	total: 116ms	remaining: 6.71s
# 17:	learn: 0.6189357	total: 120ms	remaining: 6.52s
# 18:	learn: 0.6156504	total: 122ms	remaining: 6.29s
# 19:	learn: 0.6123051	total: 124ms	remaining: 6.07s
# 20:	learn: 0.6080823	total: 127ms	remaining: 5.92s
# 21:	learn: 0.6045422	total: 129ms	remaining: 5.75s
# 22:	learn: 0.6010522	total: 132ms	remaining: 5.61s
# 23:	learn: 0.5979827	total: 134ms	remaining: 5.46s
# 24:	learn: 0.5946137	total: 138ms	remaining: 5.36s
# 25:	learn: 0.5918730	total: 138ms	remaining: 5.18s
# 26:	learn: 0.5887879	total: 141ms	remaining: 5.07s
# 27:	learn: 0.5856403	total: 143ms	remaining: 4.96s
# 28:	learn: 0.5820581	total: 147ms	remaining: 4.94s
# 29:	learn: 0.5787629	total: 150ms	remaining: 4.84s
# 30:	learn: 0.5755391	total: 160ms	remaining: 5s
# 31:	learn: 0.5723425	total: 167ms	remaining: 5.04s
# 32:	learn: 0.5691661	total: 192ms	remaining: 5.64s
# 33:	learn: 0.5663810	total: 199ms	remaining: 5.66s
# 34:	learn: 0.5636574	total: 206ms	remaining: 5.68s
# 35:	learn: 0.5612461	total: 211ms	remaining: 5.66s
# 36:	learn: 0.5579545	total: 217ms	remaining: 5.64s
# 37:	learn: 0.5550947	total: 223ms	remaining: 5.65s
# 38:	learn: 0.5523521	total: 229ms	remaining: 5.65s
# 39:	learn: 0.5497625	total: 236ms	remaining: 5.65s
# 40:	learn: 0.5471954	total: 244ms	remaining: 5.7s
# 41:	learn: 0.5438323	total: 247ms	remaining: 5.64s
# 42:	learn: 0.5416690	total: 254ms	remaining: 5.66s
# 43:	learn: 0.5387407	total: 259ms	remaining: 5.62s
# 44:	learn: 0.5359871	total: 263ms	remaining: 5.57s
# 45:	learn: 0.5328579	total: 269ms	remaining: 5.57s
# 46:	learn: 0.5296959	total: 275ms	remaining: 5.58s
# 47:	learn: 0.5272049	total: 290ms	remaining: 5.75s
# 48:	learn: 0.5240969	total: 297ms	remaining: 5.76s
# 49:	learn: 0.5210865	total: 304ms	remaining: 5.78s
# 50:	learn: 0.5184406	total: 312ms	remaining: 5.8s
# 51:	learn: 0.5152569	total: 316ms	remaining: 5.76s
# 52:	learn: 0.5134300	total: 321ms	remaining: 5.73s
# 53:	learn: 0.5104889	total: 325ms	remaining: 5.69s
# 54:	learn: 0.5073265	total: 331ms	remaining: 5.69s
# 55:	learn: 0.5044317	total: 338ms	remaining: 5.69s
# 56:	learn: 0.5018473	total: 345ms	remaining: 5.7s
# 57:	learn: 0.4990679	total: 351ms	remaining: 5.7s
# 58:	learn: 0.4961097	total: 359ms	remaining: 5.72s
# 59:	learn: 0.4949786	total: 363ms	remaining: 5.68s
# 60:	learn: 0.4927542	total: 366ms	remaining: 5.64s
# 61:	learn: 0.4906425	total: 372ms	remaining: 5.63s
# 62:	learn: 0.4879294	total: 378ms	remaining: 5.63s
# 63:	learn: 0.4856973	total: 385ms	remaining: 5.63s
# 64:	learn: 0.4833706	total: 392ms	remaining: 5.63s
# 65:	learn: 0.4808280	total: 396ms	remaining: 5.61s
# 66:	learn: 0.4782048	total: 403ms	remaining: 5.61s
# 67:	learn: 0.4760902	total: 409ms	remaining: 5.6s
# 68:	learn: 0.4734527	total: 415ms	remaining: 5.6s
# 69:	learn: 0.4710228	total: 422ms	remaining: 5.6s
# 70:	learn: 0.4690097	total: 429ms	remaining: 5.62s
# 71:	learn: 0.4666171	total: 433ms	remaining: 5.58s
# 72:	learn: 0.4649843	total: 440ms	remaining: 5.59s
# 73:	learn: 0.4626690	total: 444ms	remaining: 5.56s
# 74:	learn: 0.4605867	total: 453ms	remaining: 5.58s
# 75:	learn: 0.4587645	total: 459ms	remaining: 5.58s
# 76:	learn: 0.4566483	total: 470ms	remaining: 5.63s
# 77:	learn: 0.4551566	total: 474ms	remaining: 5.6s
# 78:	learn: 0.4532186	total: 485ms	remaining: 5.65s
# 79:	learn: 0.4511473	total: 488ms	remaining: 5.62s
# 80:	learn: 0.4493261	total: 495ms	remaining: 5.62s
# 81:	learn: 0.4472884	total: 509ms	remaining: 5.7s
# 82:	learn: 0.4449515	total: 516ms	remaining: 5.7s
# 83:	learn: 0.4432377	total: 527ms	remaining: 5.75s
# 84:	learn: 0.4409411	total: 534ms	remaining: 5.75s
# 85:	learn: 0.4389606	total: 541ms	remaining: 5.75s
# 86:	learn: 0.4365357	total: 547ms	remaining: 5.74s
# 87:	learn: 0.4347313	total: 558ms	remaining: 5.79s
# 88:	learn: 0.4333154	total: 563ms	remaining: 5.77s
# 89:	learn: 0.4316561	total: 569ms	remaining: 5.75s
# 90:	learn: 0.4298875	total: 573ms	remaining: 5.72s
# 91:	learn: 0.4279624	total: 579ms	remaining: 5.71s
# 92:	learn: 0.4260829	total: 585ms	remaining: 5.71s
# 93:	learn: 0.4241146	total: 589ms	remaining: 5.68s
# 94:	learn: 0.4220558	total: 592ms	remaining: 5.64s
# 95:	learn: 0.4202843	total: 596ms	remaining: 5.61s
# 96:	learn: 0.4181725	total: 598ms	remaining: 5.57s
# 97:	learn: 0.4163329	total: 600ms	remaining: 5.52s
# 98:	learn: 0.4142950	total: 603ms	remaining: 5.49s
# 99:	learn: 0.4124841	total: 606ms	remaining: 5.46s
# 100:	learn: 0.4110158	total: 608ms	remaining: 5.41s
# 101:	learn: 0.4093362	total: 610ms	remaining: 5.37s
# 102:	learn: 0.4071957	total: 613ms	remaining: 5.34s
# 103:	learn: 0.4053816	total: 617ms	remaining: 5.31s
# 104:	learn: 0.4035719	total: 621ms	remaining: 5.29s
# 105:	learn: 0.4024099	total: 623ms	remaining: 5.25s
# 106:	learn: 0.4007171	total: 625ms	remaining: 5.22s
# 107:	learn: 0.3991915	total: 627ms	remaining: 5.18s
# 108:	learn: 0.3972428	total: 630ms	remaining: 5.15s
# 109:	learn: 0.3954768	total: 633ms	remaining: 5.12s
# 110:	learn: 0.3937175	total: 640ms	remaining: 5.13s
# 111:	learn: 0.3918042	total: 647ms	remaining: 5.13s
# 112:	learn: 0.3903489	total: 649ms	remaining: 5.09s
# 113:	learn: 0.3884212	total: 651ms	remaining: 5.06s
# 114:	learn: 0.3865850	total: 654ms	remaining: 5.03s
# 115:	learn: 0.3849554	total: 657ms	remaining: 5.01s
# 116:	learn: 0.3832419	total: 660ms	remaining: 4.98s
# 117:	learn: 0.3816573	total: 662ms	remaining: 4.95s
# 118:	learn: 0.3801878	total: 664ms	remaining: 4.92s
# 119:	learn: 0.3786618	total: 666ms	remaining: 4.88s
# 120:	learn: 0.3770869	total: 669ms	remaining: 4.86s
# 121:	learn: 0.3754980	total: 672ms	remaining: 4.84s
# 122:	learn: 0.3742385	total: 675ms	remaining: 4.81s
# 123:	learn: 0.3729732	total: 689ms	remaining: 4.86s
# 124:	learn: 0.3716101	total: 691ms	remaining: 4.83s
# 125:	learn: 0.3702596	total: 693ms	remaining: 4.81s
# 126:	learn: 0.3685896	total: 696ms	remaining: 4.78s
# 127:	learn: 0.3669649	total: 698ms	remaining: 4.76s
# 128:	learn: 0.3656414	total: 700ms	remaining: 4.73s
# 129:	learn: 0.3640302	total: 705ms	remaining: 4.72s
# 130:	learn: 0.3627757	total: 707ms	remaining: 4.69s
# 131:	learn: 0.3610204	total: 709ms	remaining: 4.67s
# 132:	learn: 0.3596951	total: 712ms	remaining: 4.64s
# 133:	learn: 0.3584901	total: 715ms	remaining: 4.62s
# 134:	learn: 0.3568932	total: 717ms	remaining: 4.59s
# 135:	learn: 0.3556719	total: 720ms	remaining: 4.57s
# 136:	learn: 0.3541944	total: 724ms	remaining: 4.56s
# 137:	learn: 0.3526754	total: 726ms	remaining: 4.53s
# 138:	learn: 0.3516303	total: 728ms	remaining: 4.51s
# 139:	learn: 0.3502629	total: 731ms	remaining: 4.49s
# 140:	learn: 0.3488907	total: 734ms	remaining: 4.47s
# 141:	learn: 0.3473050	total: 736ms	remaining: 4.45s
# 142:	learn: 0.3461533	total: 738ms	remaining: 4.42s
# 143:	learn: 0.3450192	total: 740ms	remaining: 4.4s
# 144:	learn: 0.3437027	total: 743ms	remaining: 4.38s
# 145:	learn: 0.3424021	total: 747ms	remaining: 4.37s
# 146:	learn: 0.3410331	total: 750ms	remaining: 4.35s
# 147:	learn: 0.3398874	total: 755ms	remaining: 4.35s
# 148:	learn: 0.3387825	total: 761ms	remaining: 4.35s
# 149:	learn: 0.3374364	total: 783ms	remaining: 4.44s
# 150:	learn: 0.3362511	total: 787ms	remaining: 4.42s
# 151:	learn: 0.3351539	total: 794ms	remaining: 4.43s
# 152:	learn: 0.3340408	total: 800ms	remaining: 4.43s
# 153:	learn: 0.3333381	total: 806ms	remaining: 4.43s
# 154:	learn: 0.3320541	total: 810ms	remaining: 4.41s
# 155:	learn: 0.3311442	total: 812ms	remaining: 4.39s
# 156:	learn: 0.3303000	total: 814ms	remaining: 4.37s
# 157:	learn: 0.3296217	total: 816ms	remaining: 4.35s
# 158:	learn: 0.3285938	total: 818ms	remaining: 4.33s
# 159:	learn: 0.3273610	total: 820ms	remaining: 4.31s
# 160:	learn: 0.3260728	total: 824ms	remaining: 4.29s
# 161:	learn: 0.3249827	total: 828ms	remaining: 4.28s
# 162:	learn: 0.3239637	total: 830ms	remaining: 4.26s
# 163:	learn: 0.3227991	total: 832ms	remaining: 4.24s
# 164:	learn: 0.3215752	total: 834ms	remaining: 4.22s
# 165:	learn: 0.3204455	total: 837ms	remaining: 4.2s
# 166:	learn: 0.3195770	total: 839ms	remaining: 4.19s
# 167:	learn: 0.3184175	total: 843ms	remaining: 4.17s
# 168:	learn: 0.3172226	total: 846ms	remaining: 4.16s
# 169:	learn: 0.3159401	total: 880ms	remaining: 4.3s
# 170:	learn: 0.3148471	total: 885ms	remaining: 4.29s
# 171:	learn: 0.3137075	total: 892ms	remaining: 4.3s
# 172:	learn: 0.3124283	total: 898ms	remaining: 4.29s
# 173:	learn: 0.3114164	total: 902ms	remaining: 4.28s
# 174:	learn: 0.3102111	total: 908ms	remaining: 4.28s
# 175:	learn: 0.3091387	total: 915ms	remaining: 4.28s
# 176:	learn: 0.3083558	total: 922ms	remaining: 4.29s
# 177:	learn: 0.3072643	total: 928ms	remaining: 4.29s
# 178:	learn: 0.3065669	total: 934ms	remaining: 4.28s
# 179:	learn: 0.3054643	total: 941ms	remaining: 4.28s
# 180:	learn: 0.3045834	total: 947ms	remaining: 4.29s
# 181:	learn: 0.3037691	total: 979ms	remaining: 4.4s
# 182:	learn: 0.3025910	total: 986ms	remaining: 4.4s
# 183:	learn: 0.3014767	total: 992ms	remaining: 4.4s
# 184:	learn: 0.3006809	total: 1000ms	remaining: 4.4s
# 185:	learn: 0.2997185	total: 1s	remaining: 4.39s
# 186:	learn: 0.2985658	total: 1.01s	remaining: 4.39s
# 187:	learn: 0.2975264	total: 1.02s	remaining: 4.39s
# 188:	learn: 0.2965271	total: 1.02s	remaining: 4.38s
# 189:	learn: 0.2957540	total: 1.03s	remaining: 4.38s
# 190:	learn: 0.2946848	total: 1.03s	remaining: 4.38s
# 191:	learn: 0.2936867	total: 1.04s	remaining: 4.38s
# 192:	learn: 0.2928226	total: 1.07s	remaining: 4.47s
# 193:	learn: 0.2917795	total: 1.07s	remaining: 4.46s
# 194:	learn: 0.2909294	total: 1.08s	remaining: 4.46s
# 195:	learn: 0.2897600	total: 1.09s	remaining: 4.46s
# 196:	learn: 0.2888604	total: 1.09s	remaining: 4.46s
# 197:	learn: 0.2879989	total: 1.1s	remaining: 4.45s
# 198:	learn: 0.2871750	total: 1.1s	remaining: 4.45s
# 199:	learn: 0.2863215	total: 1.11s	remaining: 4.45s
# 200:	learn: 0.2853804	total: 1.12s	remaining: 4.44s
# 201:	learn: 0.2845609	total: 1.12s	remaining: 4.43s
# 202:	learn: 0.2836939	total: 1.13s	remaining: 4.43s
# 203:	learn: 0.2824085	total: 1.14s	remaining: 4.43s
# 204:	learn: 0.2815893	total: 1.16s	remaining: 4.51s
# 205:	learn: 0.2806949	total: 1.17s	remaining: 4.51s
# 206:	learn: 0.2797229	total: 1.18s	remaining: 4.51s
# 207:	learn: 0.2786621	total: 1.18s	remaining: 4.51s
# 208:	learn: 0.2783711	total: 1.19s	remaining: 4.49s
# 209:	learn: 0.2777369	total: 1.19s	remaining: 4.49s
# 210:	learn: 0.2771612	total: 1.2s	remaining: 4.48s
# 211:	learn: 0.2764267	total: 1.21s	remaining: 4.48s
# 212:	learn: 0.2755522	total: 1.21s	remaining: 4.48s
# 213:	learn: 0.2744422	total: 1.22s	remaining: 4.48s
# 214:	learn: 0.2734983	total: 1.23s	remaining: 4.48s
# 215:	learn: 0.2724471	total: 1.26s	remaining: 4.58s
# 216:	learn: 0.2717247	total: 1.27s	remaining: 4.57s
# 217:	learn: 0.2708726	total: 1.27s	remaining: 4.56s
# 218:	learn: 0.2702551	total: 1.28s	remaining: 4.55s
# 219:	learn: 0.2692921	total: 1.28s	remaining: 4.55s
# 220:	learn: 0.2684044	total: 1.29s	remaining: 4.55s
# 221:	learn: 0.2677039	total: 1.3s	remaining: 4.54s
# 222:	learn: 0.2668996	total: 1.3s	remaining: 4.54s
# 223:	learn: 0.2659414	total: 1.31s	remaining: 4.54s
# 224:	learn: 0.2650844	total: 1.31s	remaining: 4.53s
# 225:	learn: 0.2644190	total: 1.32s	remaining: 4.53s
# 226:	learn: 0.2635785	total: 1.33s	remaining: 4.52s
# 227:	learn: 0.2627546	total: 1.33s	remaining: 4.5s
# 228:	learn: 0.2621838	total: 1.33s	remaining: 4.49s
# 229:	learn: 0.2615703	total: 1.33s	remaining: 4.47s
# 230:	learn: 0.2607636	total: 1.36s	remaining: 4.53s
# 231:	learn: 0.2601159	total: 1.36s	remaining: 4.52s
# 232:	learn: 0.2593468	total: 1.37s	remaining: 4.52s
# 233:	learn: 0.2587436	total: 1.38s	remaining: 4.51s
# 234:	learn: 0.2579707	total: 1.4s	remaining: 4.55s
# 235:	learn: 0.2572250	total: 1.4s	remaining: 4.55s
# 236:	learn: 0.2563498	total: 1.41s	remaining: 4.54s
# 237:	learn: 0.2555651	total: 1.42s	remaining: 4.53s
# 238:	learn: 0.2550230	total: 1.42s	remaining: 4.54s
# 239:	learn: 0.2541497	total: 1.44s	remaining: 4.57s
# 240:	learn: 0.2535106	total: 1.45s	remaining: 4.57s
# 241:	learn: 0.2528053	total: 1.45s	remaining: 4.55s
# 242:	learn: 0.2523921	total: 1.46s	remaining: 4.55s
# 243:	learn: 0.2517661	total: 1.47s	remaining: 4.55s
# 244:	learn: 0.2509880	total: 1.47s	remaining: 4.54s
# 245:	learn: 0.2504313	total: 1.49s	remaining: 4.55s
# 246:	learn: 0.2499483	total: 1.49s	remaining: 4.54s
# 247:	learn: 0.2492064	total: 1.5s	remaining: 4.54s
# 248:	learn: 0.2484576	total: 1.5s	remaining: 4.54s
# 249:	learn: 0.2475504	total: 1.51s	remaining: 4.52s
# 250:	learn: 0.2467116	total: 1.51s	remaining: 4.52s
# 251:	learn: 0.2459776	total: 1.51s	remaining: 4.5s
# 252:	learn: 0.2455553	total: 1.54s	remaining: 4.55s
# 253:	learn: 0.2447764	total: 1.54s	remaining: 4.53s
# 254:	learn: 0.2442374	total: 1.55s	remaining: 4.52s
# 255:	learn: 0.2436343	total: 1.55s	remaining: 4.5s
# 256:	learn: 0.2430486	total: 1.55s	remaining: 4.49s
# 257:	learn: 0.2423577	total: 1.55s	remaining: 4.47s
# 258:	learn: 0.2419079	total: 1.56s	remaining: 4.45s
# 259:	learn: 0.2415851	total: 1.56s	remaining: 4.44s
# 260:	learn: 0.2411274	total: 1.57s	remaining: 4.44s
# 261:	learn: 0.2404668	total: 1.57s	remaining: 4.42s
# 262:	learn: 0.2397496	total: 1.57s	remaining: 4.41s
# 263:	learn: 0.2391221	total: 1.57s	remaining: 4.39s
# 264:	learn: 0.2384838	total: 1.58s	remaining: 4.38s
# 265:	learn: 0.2381089	total: 1.58s	remaining: 4.36s
# 266:	learn: 0.2374550	total: 1.58s	remaining: 4.35s
# 267:	learn: 0.2368340	total: 1.59s	remaining: 4.33s
# 268:	learn: 0.2362790	total: 1.6s	remaining: 4.34s
# 269:	learn: 0.2357705	total: 1.6s	remaining: 4.34s
# 270:	learn: 0.2350833	total: 1.61s	remaining: 4.34s
# 271:	learn: 0.2347481	total: 1.62s	remaining: 4.33s
# 272:	learn: 0.2341514	total: 1.62s	remaining: 4.33s
# 273:	learn: 0.2335722	total: 1.63s	remaining: 4.32s
# 274:	learn: 0.2329553	total: 1.64s	remaining: 4.33s
# 275:	learn: 0.2324843	total: 1.65s	remaining: 4.32s
# 276:	learn: 0.2318134	total: 1.65s	remaining: 4.32s
# 277:	learn: 0.2310525	total: 1.66s	remaining: 4.32s
# 278:	learn: 0.2304125	total: 1.67s	remaining: 4.32s
# 279:	learn: 0.2297797	total: 1.68s	remaining: 4.31s
# 280:	learn: 0.2292939	total: 1.68s	remaining: 4.3s
# 281:	learn: 0.2287281	total: 1.69s	remaining: 4.29s
# 282:	learn: 0.2282214	total: 1.69s	remaining: 4.28s
# 283:	learn: 0.2275251	total: 1.7s	remaining: 4.28s
# 284:	learn: 0.2266844	total: 1.71s	remaining: 4.29s
# 285:	learn: 0.2260781	total: 1.71s	remaining: 4.28s
# 286:	learn: 0.2256933	total: 1.72s	remaining: 4.27s
# 287:	learn: 0.2251077	total: 1.73s	remaining: 4.27s
# 288:	learn: 0.2244986	total: 1.73s	remaining: 4.27s
# 289:	learn: 0.2239623	total: 1.74s	remaining: 4.26s
# 290:	learn: 0.2234494	total: 1.74s	remaining: 4.25s
# 291:	learn: 0.2227967	total: 1.75s	remaining: 4.25s
# 292:	learn: 0.2220863	total: 1.76s	remaining: 4.24s
# 293:	learn: 0.2213930	total: 1.76s	remaining: 4.24s
# 294:	learn: 0.2211080	total: 1.77s	remaining: 4.23s
# 295:	learn: 0.2206002	total: 1.78s	remaining: 4.23s
# 296:	learn: 0.2199952	total: 1.78s	remaining: 4.22s
# 297:	learn: 0.2194898	total: 1.82s	remaining: 4.28s
# 298:	learn: 0.2188910	total: 1.82s	remaining: 4.27s
# 299:	learn: 0.2184752	total: 1.83s	remaining: 4.26s
# 300:	learn: 0.2180275	total: 1.83s	remaining: 4.26s
# 301:	learn: 0.2176592	total: 1.84s	remaining: 4.25s
# 302:	learn: 0.2172745	total: 1.84s	remaining: 4.24s
# 303:	learn: 0.2169372	total: 1.85s	remaining: 4.23s
# 304:	learn: 0.2164969	total: 1.86s	remaining: 4.23s
# 305:	learn: 0.2160354	total: 1.86s	remaining: 4.22s
# 306:	learn: 0.2155318	total: 1.87s	remaining: 4.22s
# 307:	learn: 0.2150078	total: 1.87s	remaining: 4.21s
# 308:	learn: 0.2143925	total: 1.88s	remaining: 4.2s
# 309:	learn: 0.2140170	total: 1.89s	remaining: 4.2s
# 310:	learn: 0.2134226	total: 1.89s	remaining: 4.19s
# 311:	learn: 0.2129646	total: 1.9s	remaining: 4.19s
# 312:	learn: 0.2125154	total: 1.91s	remaining: 4.18s
# 313:	learn: 0.2121332	total: 1.91s	remaining: 4.18s
# 314:	learn: 0.2115976	total: 1.92s	remaining: 4.17s
# 315:	learn: 0.2110305	total: 1.92s	remaining: 4.17s
# 316:	learn: 0.2105549	total: 1.93s	remaining: 4.16s
# 317:	learn: 0.2101811	total: 1.94s	remaining: 4.15s
# 318:	learn: 0.2097170	total: 1.94s	remaining: 4.15s
# 319:	learn: 0.2092863	total: 1.95s	remaining: 4.14s
# 320:	learn: 0.2088102	total: 1.96s	remaining: 4.14s
# 321:	learn: 0.2083418	total: 1.96s	remaining: 4.13s
# 322:	learn: 0.2077754	total: 1.97s	remaining: 4.13s
# 323:	learn: 0.2072529	total: 1.98s	remaining: 4.12s
# 324:	learn: 0.2067107	total: 1.98s	remaining: 4.12s
# 325:	learn: 0.2062961	total: 1.99s	remaining: 4.11s
# 326:	learn: 0.2060335	total: 2s	remaining: 4.11s
# 327:	learn: 0.2054853	total: 2s	remaining: 4.1s
# 328:	learn: 0.2050727	total: 2.01s	remaining: 4.1s
# 329:	learn: 0.2046903	total: 2.01s	remaining: 4.09s
# 330:	learn: 0.2043641	total: 2.02s	remaining: 4.08s
# 331:	learn: 0.2039206	total: 2.03s	remaining: 4.08s
# 332:	learn: 0.2033372	total: 2.06s	remaining: 4.12s
# 333:	learn: 0.2028048	total: 2.06s	remaining: 4.12s
# 334:	learn: 0.2024001	total: 2.07s	remaining: 4.11s
# 335:	learn: 0.2019370	total: 2.08s	remaining: 4.1s
# 336:	learn: 0.2015731	total: 2.08s	remaining: 4.1s
# 337:	learn: 0.2011776	total: 2.09s	remaining: 4.09s
# 338:	learn: 0.2006543	total: 2.1s	remaining: 4.09s
# 339:	learn: 0.2002038	total: 2.1s	remaining: 4.08s
# 340:	learn: 0.1997853	total: 2.11s	remaining: 4.08s
# 341:	learn: 0.1992961	total: 2.12s	remaining: 4.07s
# 342:	learn: 0.1987047	total: 2.12s	remaining: 4.06s
# 343:	learn: 0.1981328	total: 2.13s	remaining: 4.06s
# 344:	learn: 0.1975548	total: 2.14s	remaining: 4.06s
# 345:	learn: 0.1971306	total: 2.14s	remaining: 4.04s
# 346:	learn: 0.1967836	total: 2.15s	remaining: 4.04s
# 347:	learn: 0.1961815	total: 2.15s	remaining: 4.03s
# 348:	learn: 0.1958966	total: 2.16s	remaining: 4.03s
# 349:	learn: 0.1954770	total: 2.17s	remaining: 4.02s
# 350:	learn: 0.1950630	total: 2.17s	remaining: 4.02s
# 351:	learn: 0.1946162	total: 2.18s	remaining: 4.02s
# 352:	learn: 0.1944510	total: 2.19s	remaining: 4.01s
# 353:	learn: 0.1939340	total: 2.19s	remaining: 4s
# 354:	learn: 0.1934203	total: 2.22s	remaining: 4.03s
# 355:	learn: 0.1930699	total: 2.22s	remaining: 4.02s
# 356:	learn: 0.1926547	total: 2.22s	remaining: 4s
# 357:	learn: 0.1923114	total: 2.23s	remaining: 4.01s
# 358:	learn: 0.1918974	total: 2.24s	remaining: 3.99s
# 359:	learn: 0.1914319	total: 2.24s	remaining: 3.98s
# 360:	learn: 0.1912160	total: 2.24s	remaining: 3.96s
# 361:	learn: 0.1908226	total: 2.24s	remaining: 3.95s
# 362:	learn: 0.1904879	total: 2.25s	remaining: 3.94s
# 363:	learn: 0.1902411	total: 2.25s	remaining: 3.93s
# 364:	learn: 0.1899949	total: 2.25s	remaining: 3.92s
# 365:	learn: 0.1895949	total: 2.26s	remaining: 3.92s
# 366:	learn: 0.1890215	total: 2.26s	remaining: 3.9s
# 367:	learn: 0.1885976	total: 2.27s	remaining: 3.89s
# 368:	learn: 0.1882394	total: 2.27s	remaining: 3.88s
# 369:	learn: 0.1878683	total: 2.28s	remaining: 3.88s
# 370:	learn: 0.1876404	total: 2.28s	remaining: 3.87s
# 371:	learn: 0.1873167	total: 2.28s	remaining: 3.85s
# 372:	learn: 0.1870211	total: 2.29s	remaining: 3.84s
# 373:	learn: 0.1866282	total: 2.29s	remaining: 3.83s
# 374:	learn: 0.1861648	total: 2.29s	remaining: 3.82s
# 375:	learn: 0.1858853	total: 2.3s	remaining: 3.82s
# 376:	learn: 0.1854249	total: 2.31s	remaining: 3.81s
# 377:	learn: 0.1850818	total: 2.31s	remaining: 3.8s
# 378:	learn: 0.1848265	total: 2.31s	remaining: 3.79s
# 379:	learn: 0.1845485	total: 2.32s	remaining: 3.78s
# 380:	learn: 0.1840984	total: 2.32s	remaining: 3.77s
# 381:	learn: 0.1838546	total: 2.32s	remaining: 3.76s
# 382:	learn: 0.1833284	total: 2.33s	remaining: 3.76s
# 383:	learn: 0.1829909	total: 2.34s	remaining: 3.75s
# 384:	learn: 0.1827115	total: 2.34s	remaining: 3.74s
# 385:	learn: 0.1823292	total: 2.35s	remaining: 3.74s
# 386:	learn: 0.1818739	total: 2.35s	remaining: 3.72s
# 387:	learn: 0.1815629	total: 2.38s	remaining: 3.76s
# 388:	learn: 0.1812480	total: 2.39s	remaining: 3.75s
# 389:	learn: 0.1809565	total: 2.39s	remaining: 3.74s
# 390:	learn: 0.1805515	total: 2.4s	remaining: 3.73s
# 391:	learn: 0.1802919	total: 2.41s	remaining: 3.74s
# 392:	learn: 0.1798586	total: 2.42s	remaining: 3.75s
# 393:	learn: 0.1794833	total: 2.43s	remaining: 3.74s
# 394:	learn: 0.1791418	total: 2.44s	remaining: 3.73s
# 395:	learn: 0.1787813	total: 2.44s	remaining: 3.72s
# 396:	learn: 0.1784712	total: 2.45s	remaining: 3.72s
# 397:	learn: 0.1779729	total: 2.45s	remaining: 3.71s
# 398:	learn: 0.1775813	total: 2.48s	remaining: 3.73s
# 399:	learn: 0.1773691	total: 2.48s	remaining: 3.73s
# 400:	learn: 0.1769771	total: 2.49s	remaining: 3.72s
# 401:	learn: 0.1765440	total: 2.5s	remaining: 3.71s
# 402:	learn: 0.1762403	total: 2.5s	remaining: 3.71s
# 403:	learn: 0.1758458	total: 2.51s	remaining: 3.7s
# 404:	learn: 0.1755998	total: 2.52s	remaining: 3.7s
# 405:	learn: 0.1752962	total: 2.52s	remaining: 3.69s
# 406:	learn: 0.1749944	total: 2.53s	remaining: 3.69s
# 407:	learn: 0.1745364	total: 2.54s	remaining: 3.68s
# 408:	learn: 0.1741396	total: 2.55s	remaining: 3.68s
# 409:	learn: 0.1738184	total: 2.58s	remaining: 3.71s
# 410:	learn: 0.1736791	total: 2.58s	remaining: 3.7s
# 411:	learn: 0.1733571	total: 2.59s	remaining: 3.69s
# 412:	learn: 0.1731495	total: 2.6s	remaining: 3.69s
# 413:	learn: 0.1726757	total: 2.6s	remaining: 3.68s
# 414:	learn: 0.1723190	total: 2.61s	remaining: 3.67s
# 415:	learn: 0.1720130	total: 2.61s	remaining: 3.67s
# 416:	learn: 0.1717234	total: 2.62s	remaining: 3.67s
# 417:	learn: 0.1713022	total: 2.63s	remaining: 3.66s
# 418:	learn: 0.1709980	total: 2.63s	remaining: 3.65s
# 419:	learn: 0.1705775	total: 2.64s	remaining: 3.64s
# 420:	learn: 0.1702070	total: 2.65s	remaining: 3.64s
# 421:	learn: 0.1698704	total: 2.65s	remaining: 3.63s
# 422:	learn: 0.1695278	total: 2.68s	remaining: 3.65s
# 423:	learn: 0.1691005	total: 2.68s	remaining: 3.64s
# 424:	learn: 0.1686758	total: 2.69s	remaining: 3.63s
# 425:	learn: 0.1682118	total: 2.69s	remaining: 3.63s
# 426:	learn: 0.1678106	total: 2.7s	remaining: 3.62s
# 427:	learn: 0.1673544	total: 2.7s	remaining: 3.61s
# 428:	learn: 0.1670214	total: 2.71s	remaining: 3.61s
# 429:	learn: 0.1667719	total: 2.72s	remaining: 3.6s
# 430:	learn: 0.1664712	total: 2.72s	remaining: 3.6s
# 431:	learn: 0.1662690	total: 2.73s	remaining: 3.59s
# 432:	learn: 0.1660922	total: 2.74s	remaining: 3.58s
# 433:	learn: 0.1658591	total: 2.77s	remaining: 3.62s
# 434:	learn: 0.1656760	total: 2.78s	remaining: 3.61s
# 435:	learn: 0.1654166	total: 2.79s	remaining: 3.6s
# 436:	learn: 0.1652051	total: 2.79s	remaining: 3.6s
# 437:	learn: 0.1648529	total: 2.8s	remaining: 3.59s
# 438:	learn: 0.1645084	total: 2.81s	remaining: 3.58s
# 439:	learn: 0.1641607	total: 2.81s	remaining: 3.58s
# 440:	learn: 0.1638391	total: 2.82s	remaining: 3.57s
# 441:	learn: 0.1635030	total: 2.82s	remaining: 3.56s
# 442:	learn: 0.1631547	total: 2.83s	remaining: 3.56s
# 443:	learn: 0.1628324	total: 2.84s	remaining: 3.55s
# 444:	learn: 0.1624474	total: 2.84s	remaining: 3.54s
# 445:	learn: 0.1621422	total: 2.87s	remaining: 3.56s
# 446:	learn: 0.1620033	total: 2.87s	remaining: 3.56s
# 447:	learn: 0.1618111	total: 2.88s	remaining: 3.55s
# 448:	learn: 0.1615362	total: 2.89s	remaining: 3.54s
# 449:	learn: 0.1613133	total: 2.9s	remaining: 3.54s
# 450:	learn: 0.1609531	total: 2.9s	remaining: 3.53s
# 451:	learn: 0.1605623	total: 2.91s	remaining: 3.52s
# 452:	learn: 0.1602801	total: 2.91s	remaining: 3.52s
# 453:	learn: 0.1600868	total: 2.92s	remaining: 3.51s
# 454:	learn: 0.1596966	total: 2.93s	remaining: 3.51s
# 455:	learn: 0.1594093	total: 2.93s	remaining: 3.5s
# 456:	learn: 0.1590343	total: 2.94s	remaining: 3.49s
# 457:	learn: 0.1588236	total: 2.94s	remaining: 3.48s
# 458:	learn: 0.1584650	total: 2.97s	remaining: 3.5s
# 459:	learn: 0.1582424	total: 2.98s	remaining: 3.49s
# 460:	learn: 0.1579147	total: 2.98s	remaining: 3.49s
# 461:	learn: 0.1576547	total: 2.99s	remaining: 3.48s
# 462:	learn: 0.1573604	total: 3s	remaining: 3.48s
# 463:	learn: 0.1571597	total: 3s	remaining: 3.47s
# 464:	learn: 0.1568992	total: 3.01s	remaining: 3.46s
# 465:	learn: 0.1565247	total: 3.02s	remaining: 3.46s
# 466:	learn: 0.1562256	total: 3.02s	remaining: 3.45s
# 467:	learn: 0.1559851	total: 3.03s	remaining: 3.44s
# 468:	learn: 0.1557145	total: 3.04s	remaining: 3.44s
# 469:	learn: 0.1554796	total: 3.06s	remaining: 3.45s
# 470:	learn: 0.1550408	total: 3.07s	remaining: 3.45s
# 471:	learn: 0.1546606	total: 3.08s	remaining: 3.44s
# 472:	learn: 0.1544159	total: 3.08s	remaining: 3.44s
# 473:	learn: 0.1542389	total: 3.09s	remaining: 3.43s
# 474:	learn: 0.1540531	total: 3.1s	remaining: 3.42s
# 475:	learn: 0.1537320	total: 3.1s	remaining: 3.42s
# 476:	learn: 0.1535033	total: 3.11s	remaining: 3.41s
# 477:	learn: 0.1533129	total: 3.12s	remaining: 3.4s
# 478:	learn: 0.1530620	total: 3.12s	remaining: 3.4s
# 479:	learn: 0.1527691	total: 3.13s	remaining: 3.39s
# 480:	learn: 0.1524642	total: 3.13s	remaining: 3.38s
# 481:	learn: 0.1522156	total: 3.17s	remaining: 3.4s
# 482:	learn: 0.1518976	total: 3.17s	remaining: 3.4s
# 483:	learn: 0.1516547	total: 3.18s	remaining: 3.39s
# 484:	learn: 0.1513277	total: 3.19s	remaining: 3.39s
# 485:	learn: 0.1510548	total: 3.19s	remaining: 3.38s
# 486:	learn: 0.1508926	total: 3.2s	remaining: 3.37s
# 487:	learn: 0.1506387	total: 3.21s	remaining: 3.37s
# 488:	learn: 0.1504137	total: 3.21s	remaining: 3.36s
# 489:	learn: 0.1501651	total: 3.22s	remaining: 3.35s
# 490:	learn: 0.1498647	total: 3.23s	remaining: 3.35s
# 491:	learn: 0.1496446	total: 3.23s	remaining: 3.34s
# 492:	learn: 0.1494343	total: 3.26s	remaining: 3.36s
# 493:	learn: 0.1491619	total: 3.27s	remaining: 3.35s
# 494:	learn: 0.1488293	total: 3.28s	remaining: 3.34s
# 495:	learn: 0.1485119	total: 3.28s	remaining: 3.33s
# 496:	learn: 0.1482537	total: 3.29s	remaining: 3.33s
# 497:	learn: 0.1480105	total: 3.3s	remaining: 3.32s
# 498:	learn: 0.1477762	total: 3.3s	remaining: 3.32s
# 499:	learn: 0.1475171	total: 3.31s	remaining: 3.31s
# 500:	learn: 0.1471997	total: 3.32s	remaining: 3.3s
# 501:	learn: 0.1468205	total: 3.32s	remaining: 3.3s
# 502:	learn: 0.1465361	total: 3.33s	remaining: 3.29s
# 503:	learn: 0.1462446	total: 3.36s	remaining: 3.31s
# 504:	learn: 0.1459737	total: 3.37s	remaining: 3.3s
# 505:	learn: 0.1455930	total: 3.37s	remaining: 3.29s
# 506:	learn: 0.1452233	total: 3.38s	remaining: 3.29s
# 507:	learn: 0.1451044	total: 3.39s	remaining: 3.28s
# 508:	learn: 0.1448841	total: 3.39s	remaining: 3.27s
# 509:	learn: 0.1446618	total: 3.4s	remaining: 3.27s
# 510:	learn: 0.1444068	total: 3.41s	remaining: 3.26s
# 511:	learn: 0.1441318	total: 3.42s	remaining: 3.26s
# 512:	learn: 0.1438773	total: 3.42s	remaining: 3.25s
# 513:	learn: 0.1436790	total: 3.43s	remaining: 3.24s
# 514:	learn: 0.1434346	total: 3.44s	remaining: 3.23s
# 515:	learn: 0.1432660	total: 3.44s	remaining: 3.23s
# 516:	learn: 0.1430966	total: 3.46s	remaining: 3.23s
# 517:	learn: 0.1427349	total: 3.47s	remaining: 3.23s
# 518:	learn: 0.1424957	total: 3.48s	remaining: 3.22s
# 519:	learn: 0.1422526	total: 3.48s	remaining: 3.21s
# 520:	learn: 0.1419997	total: 3.48s	remaining: 3.2s
# 521:	learn: 0.1418032	total: 3.49s	remaining: 3.2s
# 522:	learn: 0.1413949	total: 3.5s	remaining: 3.19s
# 523:	learn: 0.1412843	total: 3.51s	remaining: 3.19s
# 524:	learn: 0.1410361	total: 3.51s	remaining: 3.18s
# 525:	learn: 0.1408632	total: 3.52s	remaining: 3.17s
# 526:	learn: 0.1406464	total: 3.52s	remaining: 3.16s
# 527:	learn: 0.1404003	total: 3.53s	remaining: 3.16s
# 528:	learn: 0.1401996	total: 3.54s	remaining: 3.15s
# 529:	learn: 0.1399588	total: 3.55s	remaining: 3.15s
# 530:	learn: 0.1397979	total: 3.56s	remaining: 3.15s
# 531:	learn: 0.1394817	total: 3.57s	remaining: 3.14s
# 532:	learn: 0.1392817	total: 3.57s	remaining: 3.13s
# 533:	learn: 0.1391459	total: 3.58s	remaining: 3.13s
# 534:	learn: 0.1390153	total: 3.59s	remaining: 3.12s
# 535:	learn: 0.1388626	total: 3.6s	remaining: 3.11s
# 536:	learn: 0.1386539	total: 3.6s	remaining: 3.1s
# 537:	learn: 0.1383978	total: 3.61s	remaining: 3.1s
# 538:	learn: 0.1382633	total: 3.61s	remaining: 3.09s
# 539:	learn: 0.1380205	total: 3.62s	remaining: 3.08s
# 540:	learn: 0.1378484	total: 3.62s	remaining: 3.07s
# 541:	learn: 0.1375534	total: 3.66s	remaining: 3.09s
# 542:	learn: 0.1372962	total: 3.66s	remaining: 3.08s
# 543:	learn: 0.1370179	total: 3.67s	remaining: 3.08s
# 544:	learn: 0.1367475	total: 3.68s	remaining: 3.07s
# 545:	learn: 0.1364739	total: 3.69s	remaining: 3.07s
# 546:	learn: 0.1363081	total: 3.69s	remaining: 3.06s
# 547:	learn: 0.1360245	total: 3.7s	remaining: 3.05s
# 548:	learn: 0.1359076	total: 3.71s	remaining: 3.04s
# 549:	learn: 0.1356914	total: 3.71s	remaining: 3.04s
# 550:	learn: 0.1353985	total: 3.72s	remaining: 3.03s
# 551:	learn: 0.1351037	total: 3.73s	remaining: 3.02s
# 552:	learn: 0.1348556	total: 3.73s	remaining: 3.02s
# 553:	learn: 0.1346559	total: 3.75s	remaining: 3.02s
# 554:	learn: 0.1344214	total: 3.76s	remaining: 3.01s
# 555:	learn: 0.1341875	total: 3.76s	remaining: 3s
# 556:	learn: 0.1340572	total: 3.77s	remaining: 3s
# 557:	learn: 0.1337280	total: 3.78s	remaining: 2.99s
# 558:	learn: 0.1335392	total: 3.78s	remaining: 2.98s
# 559:	learn: 0.1334191	total: 3.78s	remaining: 2.97s
# 560:	learn: 0.1332513	total: 3.79s	remaining: 2.96s
# 561:	learn: 0.1329989	total: 3.79s	remaining: 2.95s
# 562:	learn: 0.1327980	total: 3.79s	remaining: 2.94s
# 563:	learn: 0.1326563	total: 3.79s	remaining: 2.93s
# 564:	learn: 0.1324377	total: 3.8s	remaining: 2.92s
# 565:	learn: 0.1321282	total: 3.8s	remaining: 2.91s
# 566:	learn: 0.1319120	total: 3.8s	remaining: 2.9s
# 567:	learn: 0.1317329	total: 3.81s	remaining: 2.89s
# 568:	learn: 0.1314499	total: 3.81s	remaining: 2.88s
# 569:	learn: 0.1312332	total: 3.81s	remaining: 2.88s
# 570:	learn: 0.1310889	total: 3.81s	remaining: 2.87s
# 571:	learn: 0.1308539	total: 3.82s	remaining: 2.85s
# 572:	learn: 0.1306425	total: 3.85s	remaining: 2.87s
# 573:	learn: 0.1304606	total: 3.85s	remaining: 2.86s
# 574:	learn: 0.1302607	total: 3.85s	remaining: 2.85s
# 575:	learn: 0.1300957	total: 3.85s	remaining: 2.84s
# 576:	learn: 0.1298247	total: 3.85s	remaining: 2.83s
# 577:	learn: 0.1296776	total: 3.86s	remaining: 2.82s
# 578:	learn: 0.1294995	total: 3.86s	remaining: 2.81s
# 579:	learn: 0.1292739	total: 3.86s	remaining: 2.8s
# 580:	learn: 0.1289999	total: 3.87s	remaining: 2.79s
# 581:	learn: 0.1287937	total: 3.87s	remaining: 2.78s
# 582:	learn: 0.1286090	total: 3.87s	remaining: 2.77s
# 583:	learn: 0.1283778	total: 3.87s	remaining: 2.76s
# 584:	learn: 0.1281766	total: 3.88s	remaining: 2.75s
# 585:	learn: 0.1280500	total: 3.88s	remaining: 2.74s
# 586:	learn: 0.1278504	total: 3.88s	remaining: 2.73s
# 587:	learn: 0.1276725	total: 3.88s	remaining: 2.72s
# 588:	learn: 0.1275536	total: 3.89s	remaining: 2.71s
# 589:	learn: 0.1274057	total: 3.89s	remaining: 2.7s
# 590:	learn: 0.1272651	total: 3.89s	remaining: 2.69s
# 591:	learn: 0.1270361	total: 3.89s	remaining: 2.68s
# 592:	learn: 0.1268388	total: 3.9s	remaining: 2.67s
# 593:	learn: 0.1266591	total: 3.9s	remaining: 2.67s
# 594:	learn: 0.1264309	total: 3.9s	remaining: 2.65s
# 595:	learn: 0.1261728	total: 3.9s	remaining: 2.65s
# 596:	learn: 0.1260096	total: 3.91s	remaining: 2.64s
# 597:	learn: 0.1257967	total: 3.91s	remaining: 2.63s
# 598:	learn: 0.1256108	total: 3.91s	remaining: 2.62s
# 599:	learn: 0.1253687	total: 3.91s	remaining: 2.61s
# 600:	learn: 0.1251587	total: 3.94s	remaining: 2.62s
# 601:	learn: 0.1249449	total: 3.94s	remaining: 2.61s
# 602:	learn: 0.1247733	total: 3.94s	remaining: 2.6s
# 603:	learn: 0.1245977	total: 3.95s	remaining: 2.59s
# 604:	learn: 0.1244280	total: 3.95s	remaining: 2.58s
# 605:	learn: 0.1242152	total: 3.95s	remaining: 2.57s
# 606:	learn: 0.1240882	total: 3.96s	remaining: 2.56s
# 607:	learn: 0.1240181	total: 3.96s	remaining: 2.55s
# 608:	learn: 0.1238437	total: 3.96s	remaining: 2.54s
# 609:	learn: 0.1235933	total: 3.96s	remaining: 2.53s
# 610:	learn: 0.1233145	total: 3.96s	remaining: 2.52s
# 611:	learn: 0.1230811	total: 3.97s	remaining: 2.51s
# 612:	learn: 0.1228471	total: 3.97s	remaining: 2.5s
# 613:	learn: 0.1226620	total: 3.97s	remaining: 2.5s
# 614:	learn: 0.1224629	total: 3.98s	remaining: 2.49s
# 615:	learn: 0.1223440	total: 3.98s	remaining: 2.48s
# 616:	learn: 0.1221909	total: 3.98s	remaining: 2.47s
# 617:	learn: 0.1219120	total: 3.98s	remaining: 2.46s
# 618:	learn: 0.1216514	total: 3.99s	remaining: 2.46s
# 619:	learn: 0.1215023	total: 4s	remaining: 2.45s
# 620:	learn: 0.1213442	total: 4s	remaining: 2.44s
# 621:	learn: 0.1212549	total: 4.01s	remaining: 2.44s
# 622:	learn: 0.1210982	total: 4.04s	remaining: 2.45s
# 623:	learn: 0.1208748	total: 4.05s	remaining: 2.44s
# 624:	learn: 0.1206647	total: 4.05s	remaining: 2.43s
# 625:	learn: 0.1204597	total: 4.06s	remaining: 2.43s
# 626:	learn: 0.1203102	total: 4.07s	remaining: 2.42s
# 627:	learn: 0.1201470	total: 4.08s	remaining: 2.41s
# 628:	learn: 0.1199616	total: 4.08s	remaining: 2.41s
# 629:	learn: 0.1198066	total: 4.09s	remaining: 2.4s
# 630:	learn: 0.1195736	total: 4.09s	remaining: 2.39s
# 631:	learn: 0.1193189	total: 4.1s	remaining: 2.39s
# 632:	learn: 0.1190920	total: 4.11s	remaining: 2.38s
# 633:	learn: 0.1189243	total: 4.14s	remaining: 2.39s
# 634:	learn: 0.1187735	total: 4.15s	remaining: 2.38s
# 635:	learn: 0.1186407	total: 4.15s	remaining: 2.38s
# 636:	learn: 0.1183999	total: 4.16s	remaining: 2.37s
# 637:	learn: 0.1182610	total: 4.17s	remaining: 2.37s
# 638:	learn: 0.1180986	total: 4.18s	remaining: 2.36s
# 639:	learn: 0.1179530	total: 4.18s	remaining: 2.35s
# 640:	learn: 0.1177472	total: 4.19s	remaining: 2.34s
# 641:	learn: 0.1176060	total: 4.19s	remaining: 2.34s
# 642:	learn: 0.1174063	total: 4.2s	remaining: 2.33s
# 643:	learn: 0.1171448	total: 4.21s	remaining: 2.32s
# 644:	learn: 0.1169100	total: 4.24s	remaining: 2.33s
# 645:	learn: 0.1167221	total: 4.25s	remaining: 2.33s
# 646:	learn: 0.1165876	total: 4.25s	remaining: 2.32s
# 647:	learn: 0.1163410	total: 4.26s	remaining: 2.31s
# 648:	learn: 0.1161854	total: 4.26s	remaining: 2.31s
# 649:	learn: 0.1160356	total: 4.27s	remaining: 2.3s
# 650:	learn: 0.1158266	total: 4.28s	remaining: 2.29s
# 651:	learn: 0.1156880	total: 4.28s	remaining: 2.29s
# 652:	learn: 0.1155243	total: 4.29s	remaining: 2.28s
# 653:	learn: 0.1153108	total: 4.3s	remaining: 2.27s
# 654:	learn: 0.1151530	total: 4.3s	remaining: 2.27s
# 655:	learn: 0.1149392	total: 4.34s	remaining: 2.27s
# 656:	learn: 0.1148229	total: 4.34s	remaining: 2.27s
# 657:	learn: 0.1146771	total: 4.35s	remaining: 2.26s
# 658:	learn: 0.1145686	total: 4.36s	remaining: 2.25s
# 659:	learn: 0.1144215	total: 4.37s	remaining: 2.25s
# 660:	learn: 0.1142311	total: 4.37s	remaining: 2.24s
# 661:	learn: 0.1140686	total: 4.38s	remaining: 2.23s
# 662:	learn: 0.1139974	total: 4.38s	remaining: 2.23s
# 663:	learn: 0.1138943	total: 4.39s	remaining: 2.22s
# 664:	learn: 0.1137235	total: 4.39s	remaining: 2.21s
# 665:	learn: 0.1134825	total: 4.41s	remaining: 2.21s
# 666:	learn: 0.1133009	total: 4.41s	remaining: 2.2s
# 667:	learn: 0.1131857	total: 4.41s	remaining: 2.19s
# 668:	learn: 0.1129502	total: 4.43s	remaining: 2.19s
# 669:	learn: 0.1127564	total: 4.44s	remaining: 2.19s
# 670:	learn: 0.1125243	total: 4.44s	remaining: 2.18s
# 671:	learn: 0.1123504	total: 4.45s	remaining: 2.17s
# 672:	learn: 0.1122127	total: 4.45s	remaining: 2.16s
# 673:	learn: 0.1120703	total: 4.46s	remaining: 2.16s
# 674:	learn: 0.1118883	total: 4.47s	remaining: 2.15s
# 675:	learn: 0.1116897	total: 4.47s	remaining: 2.14s
# 676:	learn: 0.1114543	total: 4.48s	remaining: 2.14s
# 677:	learn: 0.1113077	total: 4.49s	remaining: 2.13s
# 678:	learn: 0.1112031	total: 4.49s	remaining: 2.12s
# 679:	learn: 0.1110400	total: 4.5s	remaining: 2.12s
# 680:	learn: 0.1108716	total: 4.5s	remaining: 2.11s
# 681:	learn: 0.1106987	total: 4.51s	remaining: 2.1s
# 682:	learn: 0.1105957	total: 4.52s	remaining: 2.1s
# 683:	learn: 0.1103740	total: 4.53s	remaining: 2.09s
# 684:	learn: 0.1101990	total: 4.54s	remaining: 2.09s
# 685:	learn: 0.1100707	total: 4.54s	remaining: 2.08s
# 686:	learn: 0.1098829	total: 4.55s	remaining: 2.07s
# 687:	learn: 0.1097842	total: 4.56s	remaining: 2.07s
# 688:	learn: 0.1096508	total: 4.56s	remaining: 2.06s
# 689:	learn: 0.1094343	total: 4.57s	remaining: 2.05s
# 690:	learn: 0.1092720	total: 4.58s	remaining: 2.05s
# 691:	learn: 0.1090968	total: 4.58s	remaining: 2.04s
# 692:	learn: 0.1089004	total: 4.59s	remaining: 2.03s
# 693:	learn: 0.1087642	total: 4.59s	remaining: 2.02s
# 694:	learn: 0.1085837	total: 4.6s	remaining: 2.02s
# 695:	learn: 0.1084509	total: 4.6s	remaining: 2.01s
# 696:	learn: 0.1082946	total: 4.6s	remaining: 2s
# 697:	learn: 0.1081157	total: 4.61s	remaining: 1.99s
# 698:	learn: 0.1079609	total: 4.63s	remaining: 1.99s
# 699:	learn: 0.1078185	total: 4.64s	remaining: 1.99s
# 700:	learn: 0.1077067	total: 4.64s	remaining: 1.98s
# 701:	learn: 0.1075418	total: 4.65s	remaining: 1.97s
# 702:	learn: 0.1074067	total: 4.65s	remaining: 1.97s
# 703:	learn: 0.1071846	total: 4.66s	remaining: 1.96s
# 704:	learn: 0.1070010	total: 4.66s	remaining: 1.95s
# 705:	learn: 0.1068032	total: 4.67s	remaining: 1.94s
# 706:	learn: 0.1065605	total: 4.68s	remaining: 1.94s
# 707:	learn: 0.1064168	total: 4.68s	remaining: 1.93s
# 708:	learn: 0.1062252	total: 4.69s	remaining: 1.93s
# 709:	learn: 0.1060589	total: 4.7s	remaining: 1.92s
# 710:	learn: 0.1059579	total: 4.71s	remaining: 1.91s
# 711:	learn: 0.1058091	total: 4.71s	remaining: 1.91s
# 712:	learn: 0.1056709	total: 4.71s	remaining: 1.9s
# 713:	learn: 0.1055764	total: 4.73s	remaining: 1.89s
# 714:	learn: 0.1053581	total: 4.73s	remaining: 1.89s
# 715:	learn: 0.1052450	total: 4.73s	remaining: 1.88s
# 716:	learn: 0.1050382	total: 4.74s	remaining: 1.87s
# 717:	learn: 0.1048985	total: 4.74s	remaining: 1.86s
# 718:	learn: 0.1047352	total: 4.74s	remaining: 1.85s
# 719:	learn: 0.1045319	total: 4.74s	remaining: 1.84s
# 720:	learn: 0.1044083	total: 4.75s	remaining: 1.84s
# 721:	learn: 0.1042927	total: 4.75s	remaining: 1.83s
# 722:	learn: 0.1041380	total: 4.75s	remaining: 1.82s
# 723:	learn: 0.1040465	total: 4.75s	remaining: 1.81s
# 724:	learn: 0.1039356	total: 4.76s	remaining: 1.8s
# 725:	learn: 0.1037086	total: 4.76s	remaining: 1.8s
# 726:	learn: 0.1035456	total: 4.76s	remaining: 1.79s
# 727:	learn: 0.1034172	total: 4.76s	remaining: 1.78s
# 728:	learn: 0.1032378	total: 4.77s	remaining: 1.77s
# 729:	learn: 0.1030515	total: 4.77s	remaining: 1.76s
# 730:	learn: 0.1029006	total: 4.77s	remaining: 1.76s
# 731:	learn: 0.1027004	total: 4.78s	remaining: 1.75s
# 732:	learn: 0.1025296	total: 4.78s	remaining: 1.74s
# 733:	learn: 0.1024965	total: 4.78s	remaining: 1.73s
# 734:	learn: 0.1023402	total: 4.79s	remaining: 1.73s
# 735:	learn: 0.1021454	total: 4.79s	remaining: 1.72s
# 736:	learn: 0.1019735	total: 4.79s	remaining: 1.71s
# 737:	learn: 0.1018955	total: 4.8s	remaining: 1.7s
# 738:	learn: 0.1017729	total: 4.82s	remaining: 1.7s
# 739:	learn: 0.1016067	total: 4.82s	remaining: 1.7s
# 740:	learn: 0.1014713	total: 4.83s	remaining: 1.69s
# 741:	learn: 0.1013364	total: 4.83s	remaining: 1.68s
# 742:	learn: 0.1012262	total: 4.83s	remaining: 1.67s
# 743:	learn: 0.1010535	total: 4.83s	remaining: 1.66s
# 744:	learn: 0.1009584	total: 4.84s	remaining: 1.66s
# 745:	learn: 0.1007839	total: 4.84s	remaining: 1.65s
# 746:	learn: 0.1006228	total: 4.84s	remaining: 1.64s
# 747:	learn: 0.1004884	total: 4.85s	remaining: 1.63s
# 748:	learn: 0.1003642	total: 4.85s	remaining: 1.63s
# 749:	learn: 0.1002049	total: 4.85s	remaining: 1.62s
# 750:	learn: 0.1001104	total: 4.86s	remaining: 1.61s
# 751:	learn: 0.0999645	total: 4.86s	remaining: 1.6s
# 752:	learn: 0.0998600	total: 4.86s	remaining: 1.59s
# 753:	learn: 0.0997021	total: 4.86s	remaining: 1.59s
# 754:	learn: 0.0995587	total: 4.87s	remaining: 1.58s
# 755:	learn: 0.0993968	total: 4.87s	remaining: 1.57s
# 756:	learn: 0.0992667	total: 4.87s	remaining: 1.56s
# 757:	learn: 0.0991375	total: 4.88s	remaining: 1.56s
# 758:	learn: 0.0990371	total: 4.88s	remaining: 1.55s
# 759:	learn: 0.0988849	total: 4.88s	remaining: 1.54s
# 760:	learn: 0.0987107	total: 4.89s	remaining: 1.53s
# 761:	learn: 0.0986030	total: 4.89s	remaining: 1.53s
# 762:	learn: 0.0984712	total: 4.89s	remaining: 1.52s
# 763:	learn: 0.0983695	total: 4.89s	remaining: 1.51s
# 764:	learn: 0.0981710	total: 4.9s	remaining: 1.5s
# 765:	learn: 0.0980553	total: 4.92s	remaining: 1.5s
# 766:	learn: 0.0979380	total: 4.92s	remaining: 1.5s
# 767:	learn: 0.0978404	total: 4.93s	remaining: 1.49s
# 768:	learn: 0.0976637	total: 4.93s	remaining: 1.48s
# 769:	learn: 0.0975322	total: 4.93s	remaining: 1.47s
# 770:	learn: 0.0974015	total: 4.93s	remaining: 1.47s
# 771:	learn: 0.0972937	total: 4.94s	remaining: 1.46s
# 772:	learn: 0.0971192	total: 4.94s	remaining: 1.45s
# 773:	learn: 0.0969598	total: 4.94s	remaining: 1.44s
# 774:	learn: 0.0968322	total: 4.95s	remaining: 1.44s
# 775:	learn: 0.0967795	total: 4.95s	remaining: 1.43s
# 776:	learn: 0.0966656	total: 4.95s	remaining: 1.42s
# 777:	learn: 0.0965461	total: 4.96s	remaining: 1.41s
# 778:	learn: 0.0963433	total: 4.96s	remaining: 1.41s
# 779:	learn: 0.0962468	total: 4.96s	remaining: 1.4s
# 780:	learn: 0.0961189	total: 4.96s	remaining: 1.39s
# 781:	learn: 0.0960843	total: 4.96s	remaining: 1.38s
# 782:	learn: 0.0960105	total: 4.97s	remaining: 1.38s
# 783:	learn: 0.0958653	total: 4.97s	remaining: 1.37s
# 784:	learn: 0.0957597	total: 4.98s	remaining: 1.36s
# 785:	learn: 0.0955963	total: 4.98s	remaining: 1.36s
# 786:	learn: 0.0954384	total: 4.99s	remaining: 1.35s
# 787:	learn: 0.0953247	total: 4.99s	remaining: 1.34s
# 788:	learn: 0.0952097	total: 5.02s	remaining: 1.34s
# 789:	learn: 0.0950292	total: 5.02s	remaining: 1.33s
# 790:	learn: 0.0949174	total: 5.03s	remaining: 1.33s
# 791:	learn: 0.0947815	total: 5.03s	remaining: 1.32s
# 792:	learn: 0.0945935	total: 5.04s	remaining: 1.31s
# 793:	learn: 0.0945086	total: 5.05s	remaining: 1.31s
# 794:	learn: 0.0944247	total: 5.05s	remaining: 1.3s
# 795:	learn: 0.0943129	total: 5.06s	remaining: 1.3s
# 796:	learn: 0.0942159	total: 5.07s	remaining: 1.29s
# 797:	learn: 0.0940417	total: 5.07s	remaining: 1.28s
# 798:	learn: 0.0938593	total: 5.08s	remaining: 1.28s
# 799:	learn: 0.0937437	total: 5.12s	remaining: 1.28s
# 800:	learn: 0.0936216	total: 5.12s	remaining: 1.27s
# 801:	learn: 0.0935997	total: 5.12s	remaining: 1.26s
# 802:	learn: 0.0934778	total: 5.13s	remaining: 1.26s
# 803:	learn: 0.0933312	total: 5.13s	remaining: 1.25s
# 804:	learn: 0.0932768	total: 5.14s	remaining: 1.25s
# 805:	learn: 0.0931206	total: 5.15s	remaining: 1.24s
# 806:	learn: 0.0929652	total: 5.15s	remaining: 1.23s
# 807:	learn: 0.0928060	total: 5.16s	remaining: 1.23s
# 808:	learn: 0.0926474	total: 5.17s	remaining: 1.22s
# 809:	learn: 0.0925665	total: 5.17s	remaining: 1.21s
# 810:	learn: 0.0924025	total: 5.18s	remaining: 1.21s
# 811:	learn: 0.0922534	total: 5.18s	remaining: 1.2s
# 812:	learn: 0.0921451	total: 5.21s	remaining: 1.2s
# 813:	learn: 0.0919948	total: 5.21s	remaining: 1.19s
# 814:	learn: 0.0918936	total: 5.22s	remaining: 1.18s
# 815:	learn: 0.0917739	total: 5.22s	remaining: 1.18s
# 816:	learn: 0.0916218	total: 5.22s	remaining: 1.17s
# 817:	learn: 0.0915128	total: 5.22s	remaining: 1.16s
# 818:	learn: 0.0913817	total: 5.23s	remaining: 1.16s
# 819:	learn: 0.0912550	total: 5.23s	remaining: 1.15s
# 820:	learn: 0.0911685	total: 5.23s	remaining: 1.14s
# 821:	learn: 0.0910714	total: 5.23s	remaining: 1.13s
# 822:	learn: 0.0909876	total: 5.24s	remaining: 1.13s
# 823:	learn: 0.0908615	total: 5.24s	remaining: 1.12s
# 824:	learn: 0.0906955	total: 5.24s	remaining: 1.11s
# 825:	learn: 0.0905407	total: 5.24s	remaining: 1.1s
# 826:	learn: 0.0904264	total: 5.25s	remaining: 1.1s
# 827:	learn: 0.0903714	total: 5.25s	remaining: 1.09s
# 828:	learn: 0.0902540	total: 5.25s	remaining: 1.08s
# 829:	learn: 0.0901549	total: 5.25s	remaining: 1.08s
# 830:	learn: 0.0900803	total: 5.26s	remaining: 1.07s
# 831:	learn: 0.0899620	total: 5.26s	remaining: 1.06s
# 832:	learn: 0.0898837	total: 5.26s	remaining: 1.05s
# 833:	learn: 0.0898125	total: 5.26s	remaining: 1.05s
# 834:	learn: 0.0896998	total: 5.27s	remaining: 1.04s
# 835:	learn: 0.0895892	total: 5.27s	remaining: 1.03s
# 836:	learn: 0.0895015	total: 5.27s	remaining: 1.03s
# 837:	learn: 0.0894402	total: 5.28s	remaining: 1.02s
# 838:	learn: 0.0893661	total: 5.28s	remaining: 1.01s
# 839:	learn: 0.0892563	total: 5.28s	remaining: 1s
# 840:	learn: 0.0891198	total: 5.28s	remaining: 999ms
# 841:	learn: 0.0890518	total: 5.29s	remaining: 992ms
# 842:	learn: 0.0889269	total: 5.29s	remaining: 985ms
# 843:	learn: 0.0888485	total: 5.29s	remaining: 978ms
# 844:	learn: 0.0887456	total: 5.29s	remaining: 971ms
# 845:	learn: 0.0885722	total: 5.29s	remaining: 964ms
# 846:	learn: 0.0884655	total: 5.3s	remaining: 957ms
# 847:	learn: 0.0883838	total: 5.3s	remaining: 950ms
# 848:	learn: 0.0883514	total: 5.3s	remaining: 943ms
# 849:	learn: 0.0882648	total: 5.3s	remaining: 936ms
# 850:	learn: 0.0881931	total: 5.31s	remaining: 929ms
# 851:	learn: 0.0880983	total: 5.31s	remaining: 922ms
# 852:	learn: 0.0879990	total: 5.31s	remaining: 915ms
# 853:	learn: 0.0878618	total: 5.31s	remaining: 909ms
# 854:	learn: 0.0877059	total: 5.32s	remaining: 902ms
# 855:	learn: 0.0876018	total: 5.32s	remaining: 895ms
# 856:	learn: 0.0874506	total: 5.32s	remaining: 888ms
# 857:	learn: 0.0873819	total: 5.32s	remaining: 881ms
# 858:	learn: 0.0872371	total: 5.33s	remaining: 874ms
# 859:	learn: 0.0871353	total: 5.33s	remaining: 867ms
# 860:	learn: 0.0870359	total: 5.33s	remaining: 861ms
# 861:	learn: 0.0869228	total: 5.33s	remaining: 854ms
# 862:	learn: 0.0868235	total: 5.34s	remaining: 847ms
# 863:	learn: 0.0866544	total: 5.34s	remaining: 840ms
# 864:	learn: 0.0864950	total: 5.34s	remaining: 834ms
# 865:	learn: 0.0864163	total: 5.34s	remaining: 827ms
# 866:	learn: 0.0862977	total: 5.35s	remaining: 821ms
# 867:	learn: 0.0861915	total: 5.38s	remaining: 817ms
# 868:	learn: 0.0860647	total: 5.38s	remaining: 811ms
# 869:	learn: 0.0859680	total: 5.38s	remaining: 804ms
# 870:	learn: 0.0858169	total: 5.38s	remaining: 797ms
# 871:	learn: 0.0856937	total: 5.39s	remaining: 791ms
# 872:	learn: 0.0856336	total: 5.39s	remaining: 784ms
# 873:	learn: 0.0855397	total: 5.39s	remaining: 777ms
# 874:	learn: 0.0853962	total: 5.39s	remaining: 770ms
# 875:	learn: 0.0852969	total: 5.4s	remaining: 764ms
# 876:	learn: 0.0851451	total: 5.4s	remaining: 757ms
# 877:	learn: 0.0849751	total: 5.4s	remaining: 750ms
# 878:	learn: 0.0848751	total: 5.4s	remaining: 744ms
# 879:	learn: 0.0846952	total: 5.4s	remaining: 737ms
# 880:	learn: 0.0845920	total: 5.41s	remaining: 731ms
# 881:	learn: 0.0845106	total: 5.41s	remaining: 724ms
# 882:	learn: 0.0843883	total: 5.41s	remaining: 717ms
# 883:	learn: 0.0843191	total: 5.42s	remaining: 711ms
# 884:	learn: 0.0841605	total: 5.42s	remaining: 704ms
# 885:	learn: 0.0840199	total: 5.42s	remaining: 697ms
# 886:	learn: 0.0838608	total: 5.42s	remaining: 691ms
# 887:	learn: 0.0836418	total: 5.43s	remaining: 684ms
# 888:	learn: 0.0835221	total: 5.43s	remaining: 678ms
# 889:	learn: 0.0834401	total: 5.43s	remaining: 671ms
# 890:	learn: 0.0833708	total: 5.43s	remaining: 665ms
# 891:	learn: 0.0832820	total: 5.43s	remaining: 658ms
# 892:	learn: 0.0831418	total: 5.44s	remaining: 652ms
# 893:	learn: 0.0830241	total: 5.44s	remaining: 645ms
# 894:	learn: 0.0828525	total: 5.45s	remaining: 639ms
# 895:	learn: 0.0827946	total: 5.45s	remaining: 632ms
# 896:	learn: 0.0826835	total: 5.45s	remaining: 626ms
# 897:	learn: 0.0825895	total: 5.45s	remaining: 619ms
# 898:	learn: 0.0824345	total: 5.46s	remaining: 613ms
# 899:	learn: 0.0823365	total: 5.46s	remaining: 607ms
# 900:	learn: 0.0822246	total: 5.46s	remaining: 600ms
# 901:	learn: 0.0821278	total: 5.46s	remaining: 594ms
# 902:	learn: 0.0820711	total: 5.46s	remaining: 587ms
# 903:	learn: 0.0819556	total: 5.47s	remaining: 581ms
# 904:	learn: 0.0818474	total: 5.47s	remaining: 574ms
# 905:	learn: 0.0817585	total: 5.47s	remaining: 568ms
# 906:	learn: 0.0816453	total: 5.47s	remaining: 561ms
# 907:	learn: 0.0814970	total: 5.48s	remaining: 555ms
# 908:	learn: 0.0814039	total: 5.48s	remaining: 549ms
# 909:	learn: 0.0812889	total: 5.48s	remaining: 542ms
# 910:	learn: 0.0812039	total: 5.49s	remaining: 536ms
# 911:	learn: 0.0811606	total: 5.49s	remaining: 529ms
# 912:	learn: 0.0810193	total: 5.49s	remaining: 523ms
# 913:	learn: 0.0809360	total: 5.49s	remaining: 517ms
# 914:	learn: 0.0808266	total: 5.49s	remaining: 510ms
# 915:	learn: 0.0807377	total: 5.5s	remaining: 504ms
# 916:	learn: 0.0806088	total: 5.5s	remaining: 498ms
# 917:	learn: 0.0804734	total: 5.5s	remaining: 491ms
# 918:	learn: 0.0803259	total: 5.5s	remaining: 485ms
# 919:	learn: 0.0801625	total: 5.51s	remaining: 479ms
# 920:	learn: 0.0800158	total: 5.51s	remaining: 473ms
# 921:	learn: 0.0799194	total: 5.51s	remaining: 466ms
# 922:	learn: 0.0798192	total: 5.51s	remaining: 460ms
# 923:	learn: 0.0796952	total: 5.54s	remaining: 456ms
# 924:	learn: 0.0795840	total: 5.54s	remaining: 450ms
# 925:	learn: 0.0795006	total: 5.55s	remaining: 443ms
# 926:	learn: 0.0794229	total: 5.55s	remaining: 437ms
# 927:	learn: 0.0793321	total: 5.55s	remaining: 431ms
# 928:	learn: 0.0792137	total: 5.55s	remaining: 425ms
# 929:	learn: 0.0791519	total: 5.56s	remaining: 418ms
# 930:	learn: 0.0790462	total: 5.56s	remaining: 412ms
# 931:	learn: 0.0790080	total: 5.56s	remaining: 406ms
# 932:	learn: 0.0789200	total: 5.57s	remaining: 400ms
# 933:	learn: 0.0787904	total: 5.57s	remaining: 394ms
# 934:	learn: 0.0786891	total: 5.57s	remaining: 387ms
# 935:	learn: 0.0786064	total: 5.57s	remaining: 381ms
# 936:	learn: 0.0785047	total: 5.58s	remaining: 375ms
# 937:	learn: 0.0784267	total: 5.58s	remaining: 369ms
# 938:	learn: 0.0783244	total: 5.58s	remaining: 363ms
# 939:	learn: 0.0782108	total: 5.58s	remaining: 356ms
# 940:	learn: 0.0781499	total: 5.59s	remaining: 350ms
# 941:	learn: 0.0780793	total: 5.59s	remaining: 344ms
# 942:	learn: 0.0779652	total: 5.59s	remaining: 338ms
# 943:	learn: 0.0778765	total: 5.6s	remaining: 332ms
# 944:	learn: 0.0777476	total: 5.6s	remaining: 326ms
# 945:	learn: 0.0776607	total: 5.61s	remaining: 320ms
# 946:	learn: 0.0775839	total: 5.62s	remaining: 314ms
# 947:	learn: 0.0774864	total: 5.64s	remaining: 309ms
# 948:	learn: 0.0773792	total: 5.64s	remaining: 303ms
# 949:	learn: 0.0773161	total: 5.66s	remaining: 298ms
# 950:	learn: 0.0772282	total: 5.67s	remaining: 292ms
# 951:	learn: 0.0771100	total: 5.67s	remaining: 286ms
# 952:	learn: 0.0769906	total: 5.68s	remaining: 280ms
# 953:	learn: 0.0769044	total: 5.68s	remaining: 274ms
# 954:	learn: 0.0767844	total: 5.69s	remaining: 268ms
# 955:	learn: 0.0766913	total: 5.7s	remaining: 262ms
# 956:	learn: 0.0766114	total: 5.71s	remaining: 256ms
# 957:	learn: 0.0765343	total: 5.71s	remaining: 250ms
# 958:	learn: 0.0764507	total: 5.72s	remaining: 244ms
# 959:	learn: 0.0763607	total: 5.74s	remaining: 239ms
# 960:	learn: 0.0761921	total: 5.74s	remaining: 233ms
# 961:	learn: 0.0760978	total: 5.75s	remaining: 227ms
# 962:	learn: 0.0760233	total: 5.75s	remaining: 221ms
# 963:	learn: 0.0759250	total: 5.75s	remaining: 215ms
# 964:	learn: 0.0758506	total: 5.75s	remaining: 209ms
# 965:	learn: 0.0757680	total: 5.76s	remaining: 203ms
# 966:	learn: 0.0756976	total: 5.76s	remaining: 197ms
# 967:	learn: 0.0756393	total: 5.76s	remaining: 191ms
# 968:	learn: 0.0755469	total: 5.77s	remaining: 184ms
# 969:	learn: 0.0754778	total: 5.77s	remaining: 178ms
# 970:	learn: 0.0753600	total: 5.77s	remaining: 172ms
# 971:	learn: 0.0752946	total: 5.77s	remaining: 166ms
# 972:	learn: 0.0752198	total: 5.78s	remaining: 160ms
# 973:	learn: 0.0751545	total: 5.78s	remaining: 154ms
# 974:	learn: 0.0750440	total: 5.78s	remaining: 148ms
# 975:	learn: 0.0749808	total: 5.78s	remaining: 142ms
# 976:	learn: 0.0748714	total: 5.78s	remaining: 136ms
# 977:	learn: 0.0747708	total: 5.79s	remaining: 130ms
# 978:	learn: 0.0746753	total: 5.79s	remaining: 124ms
# 979:	learn: 0.0745293	total: 5.79s	remaining: 118ms
# 980:	learn: 0.0744463	total: 5.79s	remaining: 112ms
# 981:	learn: 0.0743450	total: 5.8s	remaining: 106ms
# 982:	learn: 0.0742525	total: 5.8s	remaining: 100ms
# 983:	learn: 0.0741795	total: 5.8s	remaining: 94.3ms
# 984:	learn: 0.0740800	total: 5.8s	remaining: 88.4ms
# 985:	learn: 0.0739843	total: 5.81s	remaining: 82.5ms
# 986:	learn: 0.0738733	total: 5.81s	remaining: 76.5ms
# 987:	learn: 0.0737979	total: 5.81s	remaining: 70.6ms
# 988:	learn: 0.0737614	total: 5.82s	remaining: 64.7ms
# 989:	learn: 0.0736934	total: 5.82s	remaining: 58.8ms
# 990:	learn: 0.0735694	total: 5.82s	remaining: 52.9ms
# 991:	learn: 0.0734856	total: 5.82s	remaining: 47ms
# 992:	learn: 0.0733791	total: 5.83s	remaining: 41.1ms
# 993:	learn: 0.0732830	total: 5.83s	remaining: 35.2ms
# 994:	learn: 0.0731647	total: 5.83s	remaining: 29.3ms
# 995:	learn: 0.0730697	total: 5.83s	remaining: 23.4ms
# 996:	learn: 0.0730068	total: 5.84s	remaining: 17.6ms
# 997:	learn: 0.0729100	total: 5.84s	remaining: 11.7ms
# 998:	learn: 0.0728562	total: 5.84s	remaining: 5.85ms
# 999:	learn: 0.0727961	total: 5.84s	remaining: 0us
# <style  type="text/css" >
# #T_abb45_row0_col1,#T_abb45_row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 92.0%, transparent 92.0%);
#         }#T_abb45_row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 92.5%, transparent 92.5%);
#         }#T_abb45_row1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 91.1%, transparent 91.1%);
#         }#T_abb45_row2_col1,#T_abb45_row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 90.0%, transparent 90.0%);
#         }#T_abb45_row2_col2,#T_abb45_row3_col2,#T_abb45_row4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 88.1%, transparent 88.1%);
#         }#T_abb45_row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 88.0%, transparent 88.0%);
#         }#T_abb45_row5_col1,#T_abb45_row6_col1,#T_abb45_row7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 86.0%, transparent 86.0%);
#         }#T_abb45_row5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 86.5%, transparent 86.5%);
#         }#T_abb45_row6_col2,#T_abb45_row7_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 85.1%, transparent 85.1%);
#         }#T_abb45_row8_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 78.0%, transparent 78.0%);
#         }#T_abb45_row8_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 76.2%, transparent 76.2%);
#         }</style><table id="T_abb45_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >Bal Acc.</th>        <th class="col_heading level0 col3" >Time</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_abb45_level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_abb45_row0_col0" class="data row0 col0" >KNeighborsClassifier</td>
#                         <td id="T_abb45_row0_col1" class="data row0 col1" >92.000000</td>
#                         <td id="T_abb45_row0_col2" class="data row0 col2" >92.513369</td>
#                         <td id="T_abb45_row0_col3" class="data row0 col3" >0.070820</td>
#             </tr>
#             <tr>
#                         <th id="T_abb45_level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_abb45_row1_col0" class="data row1 col0" >GradientBoostingClassifier</td>
#                         <td id="T_abb45_row1_col1" class="data row1 col1" >92.000000</td>
#                         <td id="T_abb45_row1_col2" class="data row1 col2" >91.087344</td>
#                         <td id="T_abb45_row1_col3" class="data row1 col3" >0.255282</td>
#             </tr>
#             <tr>
#                         <th id="T_abb45_level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_abb45_row2_col0" class="data row2 col0" >RandomForestClassifier</td>
#                         <td id="T_abb45_row2_col1" class="data row2 col1" >90.000000</td>
#                         <td id="T_abb45_row2_col2" class="data row2 col2" >88.146168</td>
#                         <td id="T_abb45_row2_col3" class="data row2 col3" >0.330698</td>
#             </tr>
#             <tr>
#                         <th id="T_abb45_level0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_abb45_row3_col0" class="data row3 col0" >CatBoostClassifier</td>
#                         <td id="T_abb45_row3_col1" class="data row3 col1" >90.000000</td>
#                         <td id="T_abb45_row3_col2" class="data row3 col2" >88.146168</td>
#                         <td id="T_abb45_row3_col3" class="data row3 col3" >6.493486</td>
#             </tr>
#             <tr>
#                         <th id="T_abb45_level0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_abb45_row4_col0" class="data row4 col0" >XGBClassifier</td>
#                         <td id="T_abb45_row4_col1" class="data row4 col1" >88.000000</td>
#                         <td id="T_abb45_row4_col2" class="data row4 col2" >88.057041</td>
#                         <td id="T_abb45_row4_col3" class="data row4 col3" >3.284616</td>
#             </tr>
#             <tr>
#                         <th id="T_abb45_level0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_abb45_row5_col0" class="data row5 col0" >LogisticRegression</td>
#                         <td id="T_abb45_row5_col1" class="data row5 col1" >86.000000</td>
#                         <td id="T_abb45_row5_col2" class="data row5 col2" >86.541889</td>
#                         <td id="T_abb45_row5_col3" class="data row5 col3" >0.123781</td>
#             </tr>
#             <tr>
#                         <th id="T_abb45_level0_row6" class="row_heading level0 row6" >7</th>
#                         <td id="T_abb45_row6_col0" class="data row6 col0" >AdaBoostClassifier</td>
#                         <td id="T_abb45_row6_col1" class="data row6 col1" >86.000000</td>
#                         <td id="T_abb45_row6_col2" class="data row6 col2" >85.115865</td>
#                         <td id="T_abb45_row6_col3" class="data row6 col3" >0.217952</td>
#             </tr>
#             <tr>
#                         <th id="T_abb45_level0_row7" class="row_heading level0 row7" >8</th>
#                         <td id="T_abb45_row7_col0" class="data row7 col0" >LGBMClassifier</td>
#                         <td id="T_abb45_row7_col1" class="data row7 col1" >86.000000</td>
#                         <td id="T_abb45_row7_col2" class="data row7 col2" >85.115865</td>
#                         <td id="T_abb45_row7_col3" class="data row7 col3" >1.003535</td>
#             </tr>
#             <tr>
#                         <th id="T_abb45_level0_row8" class="row_heading level0 row8" >9</th>
#                         <td id="T_abb45_row8_col0" class="data row8 col0" >DecisionTreeClassifier</td>
#                         <td id="T_abb45_row8_col1" class="data row8 col1" >78.000000</td>
#                         <td id="T_abb45_row8_col2" class="data row8 col2" >76.203209</td>
#                         <td id="T_abb45_row8_col3" class="data row8 col3" >0.070544</td>
#             </tr>
#     </tbody></table>

# %%
#with the best  paramaters
classifier=ensemble.RandomForestClassifier()
tuning_model=Pipeline(steps=[('preprocessor', preprocessor),('classifier',classifier )])
tuning_model.fit(x_train,y_train)
print("model score: %.3f" % tuning_model.score(x_val, y_val))
# Out:
# model score: 0.900

# %%
import streamlit as st
import base64
import sklearn
import numpy as np
import pickle as pkl
from sklearn.preprocessing import MinMaxScaler
import chime

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import sklearn as skl
import sklearn
from sklearn import pipeline      
from sklearn import preprocessing 
from sklearn import model_selection 
from sklearn import metrics         
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier

scal = MinMaxScaler()

#Load the saved model
model=pkl.load(open("final_model.p","rb"))


st.set_page_config(page_title="Heart App",page_icon="⚕️",layout="centered",initial_sidebar_state="expanded")


def preprocess(age,sex,cp,trestbps,restecg,chol,fbs,thalach,exang,oldpeak,slope,ca,thal ):   
 
    # Pre-processing user input   
    if sex=="male":
        sex=1 
    else: sex=0
    
    
    if cp=="Typical angina":
        cp=0
    elif cp=="Atypical angina":
        cp=1
    elif cp=="Non-anginal pain":
        cp=2
    elif cp=="Asymptomatic":
        cp=2
    
    if exang=="Yes":
        exang=1
    elif exang=="No":
        exang=0
 
    if fbs=="Yes":
        fbs=1
    elif fbs=="No":
        fbs=0
 
    if slope=="Upsloping: better heart rate with excercise(uncommon)":
        slope=0
    elif slope=="Flatsloping: minimal change(typical healthy heart)":
          slope=1
    elif slope=="Downsloping: signs of unhealthy heart":
        slope=2  
 
    if thal=="fixed defect: used to be defect but ok now":
        thal=6
    elif thal=="reversable defect: no proper blood movement when excercising":
        thal=7
    elif thal=="normal":
        thal=2.31

    if restecg=="Nothing to note":
        restecg=0
    elif restecg=="ST-T Wave abnormality":
        restecg=1
    elif restecg=="Possible or definite left ventricular hypertrophy":
        restecg=2


    user_input=[age,sex,cp,trestbps,restecg,chol,fbs,thalach,exang,oldpeak,slope,ca,thal]
    user_input=np.array(user_input)
    user_input=user_input.reshape(1,-1)
    user_input=scal.fit_transform(user_input)
    prediction = model.predict(user_input)

    return prediction

    
       
    # front end elements of the web page 
html_temp = """ 
    <div style ="background-color:pink;padding:13px"> 
    <h1 style ="color:black;text-align:center;">Healthy Heart App</h1> 
    </div> 
    """
      
# display the front end aspect
st.markdown(html_temp, unsafe_allow_html = True) 
st.subheader('by Ramon y Cajal Strive team ')
      
# following lines create boxes in which user can enter data required to make prediction
age = st.selectbox ("Age",range(1,121,1))
sex = st.radio("Select Gender: ", ('male', 'female'))
cp = st.selectbox('Chest Pain Type',("Typical angina","Atypical angina","Non-anginal pain","Asymptomatic")) 
trestbps=st.selectbox('Resting Blood Sugar',range(1,500,1))
restecg=st.selectbox('Resting Electrocardiographic Results',("Nothing to note","ST-T Wave abnormality","Possible or definite left ventricular hypertrophy"))
chol=st.selectbox('Serum Cholestoral in mg/dl',range(1,1000,1))
fbs=st.radio("Fasting Blood Sugar higher than 120 mg/dl", ['Yes','No'])
thalach=st.selectbox('Maximum Heart Rate Achieved',range(1,300,1))
exang=st.selectbox('Exercise Induced Angina',["Yes","No"])
oldpeak=st.number_input('Oldpeak')
slope = st.selectbox('Heart Rate Slope',("Upsloping: better heart rate with excercise(uncommon)","Flatsloping: minimal change(typical healthy heart)","Downsloping: signs of unhealthy heart"))
ca=st.selectbox('Number of Major Vessels Colored by Flourosopy',range(0,5,1))
thal=st.selectbox('Thalium Stress Result',range(1,8,1))



#user_input=preprocess(sex,cp,exang, fbs, slope, thal )
pred=preprocess(age,sex,cp,trestbps,restecg,chol,fbs,thalach,exang,oldpeak,slope,ca,thal)

audio_file = open('alarm.mp3', 'rb').read()


if st.button("Predict"):    
  if pred[0] == 0:
    st.error('Warning! You have high risk of getting a heart attack!')
    chime.warning()
    st.audio(audio_file, format='audio/mp3')

  else:
    st.success('You have lower risk of getting a heart attack!')
    chime.success()
    st.audio(audio_file, format='audio/mp3')


st.sidebar.subheader("About App")

st.sidebar.info("This web app is helps you to find out whether you are at a risk of developing a heart disease.")
st.sidebar.info("Enter the required fields and click on the 'Predict' button to check whether you have a healthy heart")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-498c4387bd22> in <module>
#      23
#      24 #Load the saved model
# ---> 25 model=pkl.load(open("final_model.p","rb"))
#      26
#      27
#
# FileNotFoundError: [Errno 2] No such file or directory: 'final_model.p'

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=cd775439-f3d2-4e6d-9916-a56701a1b233' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
