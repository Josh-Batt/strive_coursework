# %%
import pandas as pd
import sweetviz as sv

# %%
book_df = pd.read_csv("final_01.csv")
book_df
# Out:
#      Unnamed: 0                                                url  \
# 0             0  https://www.goodreads.com//book/show/13496.A_G...
# 1             1  https://www.goodreads.com//book/show/30.J_R_R_...
# 2             2  https://www.goodreads.com//book/show/186074.Th...
# 3             3  https://www.goodreads.com//book/show/7235533-t...
# 4             4  https://www.goodreads.com//book/show/11127.The...
# ..          ...                                                ...
# 995         995  https://www.goodreads.com//book/show/17315.Oat...
# 996         996  https://www.goodreads.com//book/show/1539021.A...
# 997         997  https://www.goodreads.com//book/show/517104.Co...
# 998         998  https://www.goodreads.com//book/show/15547.Mag...
# 999         999  https://www.goodreads.com//book/show/15881.Har...
#
#                                                  title              author  \
# 0                                    A Game of Thrones  George R.R. Martin
# ...

# %%
comparison_report = sv.compare([book_df,'num_ratings'], [book_df,'num_reviews'], target_feat='avg_rating')
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:01 -> (00:00 left)

# %%
comparison_report.show_notebook()
# Out:
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# ...
