# %%
# %matplotlib inline

import warnings
import numpy as np
import pandas as pd
import scipy.stats as st
import statsmodels as sm
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %%
# became obselte
#df1 = pd.read_csv('../TH_Data/500_rows.csv', index_col=0)

# Load second 500 rows from csv
#df2 = pd.read_csv('../TH_Data/500_2_rows.csv', index_col=0)

# Concatenate dfs
#frames = [df1, df2]
#df = pd.concat(frames, ignore_index=True)

# %%
df = pd.read_csv('final_01.csv', index_col=0)
#df

# %% [markdown]
# ## Task 1

# %%
# Task 1
df = df.sort_values('num_ratings', ascending = True)
df.plot.scatter('num_pages' ,'num_ratings', color = 'r', edgecolor = 'b')
# Out:
# <AxesSubplot:xlabel='num_pages', ylabel='num_ratings'>

# %% [markdown]
# ## Task 2

# %%
df['num_pages'].corr(df['num_ratings'])
# Out:
# -0.019666368203704942

# %% [markdown]
# ## TASK 3

# %%
avg_reviews = df['avg_rating'].tolist()
plt.hist(avg_reviews, edgecolor = "white")
plt.xlabel("Averge Rating")
plt.ylabel("Number of books with rating")
# Out:
# Text(0, 0.5, 'Number of books with rating')

# %% [markdown]
# ## Task 4, 5

# %%
df1 = df

# min-max
max_min_value = df['avg_rating'].max() - df['avg_rating'].min()
min_value = df['avg_rating'].min()
df1['minmax_norm_ratings'] = 1 + (df1['avg_rating'] - min_value) / (max_min_value) * 9

# %%
# Plots the histogram of the normalized version of a column compared with the not normalized one

def plot_norm(not_norm_series, norm_series, norm_type: str, bins_ = 20, not_norm_color='#e67e4d', norm_color='#e67eff', edgecolor_='black'):
    
    # defining some useful variables
    norm_min = round(norm_series.min(), 2)
    norm_max = round(norm_series.max(), 2)

    
    # Set the number of subplots and the fig dimensions
    fig, ax = plt.subplots(1, 2, figsize = (15,7))

    # defining the not-normilized graph
    ax[0].hist(not_norm_series, bins=bins_, color=not_norm_color, histtype='bar', edgecolor=edgecolor_)
    ax[0].set_title("Not normalized")
    ax[0].set_xlabel('Ratings')
    ax[0].set_ylabel('Frequency')

    # defining the normilized graph
    ax[1].hist(norm_series, bins=bins_, color=norm_color, histtype='bar', edgecolor=edgecolor_)
    ax[1].set_title(norm_type)
    ax[1].set_xlabel(f'Ratings (normalized {norm_min} to {norm_max})')
    ax[1].set_ylabel('Frequency')

    # Set the ticks for x axis in normalized graph, according to the data range
    plt.sca(ax[1])
    plt.xticks(np.arange(norm_min, norm_max + 1, 1))

# Examples
plot_norm(df1.avg_rating, df1.minmax_norm_ratings, norm_type='Min-Max normalization')
plot_norm(df1.avg_rating, df1.mean_norm_ratings, norm_type='Mean normalization')

# %% [markdown]
# ## Task 6

# %%
df['minmax_norm_ratings'] = (df['avg_rating'] - df['avg_rating'].min()) / (df['avg_rating'].max() - df['avg_rating'].min())
df['mean_norm_ratings'] =  (df['avg_rating'] - df['avg_rating'].mean()) / (df['avg_rating'].max() - df['avg_rating'].min())

def plot_compared_norms(first_norm, second_norm, first_norm_type: str, second_norm_type: str, \
    bins_ = 20, first_norm_color='blue',second_norm_color='darkorange', edgecolor_='white'):
    min_range = round(np.array([first_norm.min(), second_norm.min()]).min(), 2)
    max_range = round(np.array([first_norm.max(), second_norm.max()]).max(), 2)


    # Set the fig dimensions
    fig, graph = plt.subplots(figsize = (15, 8))
    
    # defining the normilized graph
    graph.hist(first_norm, bins = bins_, alpha = 0.7, color=first_norm_color, edgecolor = edgecolor_, label = first_norm_type)
    graph.hist(second_norm, bins = bins_, alpha = 0.7, color=second_norm_color, edgecolor = edgecolor_, label = second_norm_type)
    graph.set_title(f'Comparison between {first_norm_type} and {second_norm_type}')
    graph.legend()
    
    # Set the range of the ticks in x axis, according to data range
    graph.set_xlabel(f'Range between min: {min_range} and max: {max_range}')

# Example
plot_compared_norms(df.minmax_norm_ratings, df.mean_norm_ratings, first_norm_type = 'Min-Max normalization', second_norm_type='Mean normalization')

# %%
# Load first 1000 rows from csv

# normalizing avg_ratings with MinMax and Mean
df['minmax_norm_ratings'] = (df['avg_rating'] - df['avg_rating'].min()) / (df['avg_rating'].max() - df['avg_rating'].min())
df['mean_norm_ratings'] =  (df['avg_rating'] - df['avg_rating'].mean()) / (df['avg_rating'].max() - df['avg_rating'].min())
# df['minmax_norm'] = 1 + (df['avg_rating'] - df['avg_rating'].min()) / (df['avg_rating'].max() - df['avg_rating'].min()) * 9
# df['mean_norm'] = 1 + (df['avg_rating'] - df['avg_rating'].mean()) / (df['avg_rating'].max() - df['avg_rating'].min()) * 9

#display(df.head())

# %% [markdown]
# ## Task 7

# %%
# Create models from data
def best_fit_distribution(data, bins=20, ax=None):
    """Model data by finding best fit distribution to data"""
    # Get histogram of original data
    y, x = np.histogram(data, bins=bins, density=True)
    x = (x + np.roll(x, -1))[:-1] / 2.0

    # Distributions to check
    DISTRIBUTIONS = [        
        st.alpha,st.anglit,st.arcsine,st.beta,st.betaprime,st.bradford,st.burr,st.cauchy,st.chi,st.chi2,st.cosine,
        st.dgamma,st.dweibull,st.erlang,st.expon,st.exponnorm,st.exponweib,st.exponpow,st.f,st.fatiguelife,st.fisk,
        st.foldcauchy,st.foldnorm,st.genlogistic,st.genpareto,st.gennorm,st.genexpon,
        st.genextreme,st.gausshyper,st.gamma,st.gengamma,st.genhalflogistic,st.gilbrat,st.gompertz,st.gumbel_r,
        st.gumbel_l,st.halfcauchy,st.halflogistic,st.halfnorm,st.halfgennorm,st.hypsecant,st.invgamma,st.invgauss,
        st.invweibull,st.johnsonsb,st.johnsonsu,st.ksone,st.kstwobign,st.laplace,st.levy,st.levy_l,st.levy_stable,
        st.logistic,st.loggamma,st.loglaplace,st.lognorm,st.lomax,st.maxwell,st.mielke,st.nakagami,st.ncx2,st.ncf,
        st.nct,st.norm,st.pareto,st.pearson3,st.powerlaw,st.powerlognorm,st.powernorm,st.rdist,st.reciprocal,
        st.rayleigh,st.rice,st.recipinvgauss,st.semicircular,st.t,st.triang,st.truncexpon,st.truncnorm,st.tukeylambda,
        st.uniform,st.vonmises,st.vonmises_line,st.wald,st.weibull_min,st.weibull_max,st.wrapcauchy
    ]

    # Best holders
    best_distribution = st.norm
    best_params = (0.0, 1.0)
    best_sse = np.inf

    # Estimate distribution parameters from data
    for distribution in DISTRIBUTIONS:

        # Try to fit the distribution
        try:
            # Ignore warnings from data that can't be fit
            with warnings.catch_warnings():
                warnings.filterwarnings('ignore')

                # fit dist to data
                params = distribution.fit(data)

                # Separate parts of parameters
                arg = params[:-2]
                loc = params[-2]
                scale = params[-1]

                # Calculate fitted PDF and error with fit in distribution
                pdf = distribution.pdf(x, loc=loc, scale=scale, *arg)
                sse = np.sum(np.power(y - pdf, 2.0))

                # if axis pass in add to plot
                try:
                    if ax:
                        pd.Series(pdf, x).plot(ax=ax)
                    end
                except Exception:
                    pass

                # identify if this distribution is better
                if best_sse > sse > 0:
                    best_distribution = distribution
                    best_params = params
                    best_sse = sse

        except Exception:
            pass

    return (best_distribution.name, best_params)

def make_pdf(dist, params, size=10000):
    """Generate distributions's Probability Distribution Function """

    # Separate parts of parameters
    arg = params[:-2]
    loc = params[-2]
    scale = params[-1]

    # Get sane start and end points of distribution
    start = dist.ppf(0.01, *arg, loc=loc, scale=scale) if arg else dist.ppf(0.01, loc=loc, scale=scale)
    end = dist.ppf(0.99, *arg, loc=loc, scale=scale) if arg else dist.ppf(0.99, loc=loc, scale=scale)

    # Build PDF and turn into pandas Series
    x = np.linspace(start, end, size)
    y = dist.pdf(x, loc=loc, scale=scale, *arg)
    pdf = pd.Series(y, x)

    return pdf

# Plots the best fit distribution given a pandas series, the title and the labels
def plot_best_fit_distribution(data: pd.Series, title: str, xlabel: str, ylabel: str):

    matplotlib.rcParams['figure.figsize'] = (16.0, 12.0)
    matplotlib.style.use('ggplot')

    # Plot for comparison
    plt.figure(figsize=(12,8))
    # ax = df.minmax_norm.plot(kind='hist', bins=20, normed=True, alpha=0.5, color=plt.rcParams['axes.color_cycle'][1])
    # ax = df.minmax_norm.plot(kind='hist', bins=20, alpha=0.5, color='blue', edgecolor = 'white')
    ax = data.hist(bins=20, alpha=0.5, density=True, color='blue', edgecolor = 'white')
    # Save plot limits
    dataYLim = ax.get_ylim()

    # Find best fit distribution
    best_fit_name, best_fit_params = best_fit_distribution(data, 20, ax)
    best_dist = getattr(st, best_fit_name)

    # Update plots
    ax.set_ylim(dataYLim)
    ax.set_title(f'{title} \n All Fitted Distributions')
    ax.set_xlabel(u'Normalized ratings 1 - 10')
    ax.set_ylabel('Frequency')

    # Make PDF with best params 
    pdf = make_pdf(best_dist, best_fit_params)

    # Display
    plt.figure(figsize=(12,8))
    ax = pdf.plot(lw=2, label='PDF', legend=True)
    data.plot(kind='hist', bins=20, alpha=0.5, density=True, label='Data', legend=True, ax=ax)

    param_names = (best_dist.shapes + ', loc, scale').split(', ') if best_dist.shapes else ['loc', 'scale']
    param_str = ', '.join(['{}={:0.2f}'.format(k,v) for k,v in zip(param_names, best_fit_params)])
    dist_str = '{}({})'.format(best_fit_name, param_str)

    # ax.set_title(u'Min Max normalized rating with best fit distribution \n' + dist_str)
    ax.set_title(f'{title} with best fit distribution \n {dist_str}')
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)

plot_best_fit_distribution(df.minmax_norm_ratings, title='Min-Max Average Ratings Normalization', xlabel='Normalized ratings', ylabel='Frequency')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-941fe35fccb4> in <module>
#     125     ax.set_ylabel(ylabel)
#     126
# --> 127 plot_best_fit_distribution(df.minmax_norm_ratings, title='Min-Max Average Ratings Normalization', xlabel='Normalized ratings', ylabel='Frequency')
#
# <ipython-input-35-941fe35fccb4> in plot_best_fit_distribution(data, title, xlabel, ylabel)
#      99
#     100     # Find best fit distribution
# --> 101     best_fit_name, best_fit_params = best_fit_distribution(data, 20, ax)
#     102     best_dist = getattr(st, best_fit_name)
#     103
#
# <ipython-input-35-941fe35fccb4> in best_fit_distribution(data, bins, ax)
#      35
#      36                 # fit dist to data
# ---> 37                 params = distribution.fit(data)
#      38
#      39                 # Separate parts of parameters
#
# ~/anaconda3/envs/StriveSchool/lib/python3.9/site-packages/scipy/stats/_distn_infrastructure.py in fit(self, data, *args, **kwds)
#    2395             raise TypeError("Unknown arguments: %s." % kwds)
#    2396
# -> 2397         vals = optimizer(func, x0, args=(ravel(data),), disp=0)
#    2398         if restore is not None:
#    2399             vals = restore(args, vals)
#
# ~/anaconda3/envs/StriveSchool/lib/python3.9/site-packages/scipy/optimize/optimize.py in fmin(func, x0, args, xtol, ftol, maxiter, maxfun, full_output, disp, retall, callback, initial_simplex)
#     575             'initial_simplex': initial_simplex}
#     576
# --> 577     res = _minimize_neldermead(func, x0, args, callback=callback, **opts)
#     578     if full_output:
#     579         retlist = res['x'], res['fun'], res['nit'], res['nfev'], res['status']
#
# ~/anaconda3/envs/StriveSchool/lib/python3.9/site-packages/scipy/optimize/optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, **unknown_options)
#     737         xbar = np.add.reduce(sim[:-1], 0) / N
#     738         xr = (1 + rho) * xbar - rho * sim[-1]
# --> 739         fxr = func(xr)
#     740         doshrink = 0
#     741
#
# ~/anaconda3/envs/StriveSchool/lib/python3.9/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     459     def function_wrapper(*wrapper_args):
#     460         ncalls[0] += 1
# --> 461         return function(*(wrapper_args + args))
#     462
#     463     return ncalls, function_wrapper
#
# ~/anaconda3/envs/StriveSchool/lib/python3.9/site-packages/scipy/stats/_distn_infrastructure.py in _penalized_nnlf(self, theta, x)
#    2207         x = asarray((x-loc) / scale)
#    2208         n_log_scale = len(x) * log(scale)
# -> 2209         return self._nnlf_and_penalty(x, args) + n_log_scale
#    2210
#    2211     # return starting point for fit (shape arguments + loc + scale)
#
# ~/anaconda3/envs/StriveSchool/lib/python3.9/site-packages/scipy/stats/_distn_infrastructure.py in _nnlf_and_penalty(self, x, args)
#    2189         if n_bad > 0:
#    2190             x = argsreduce(~cond0, x)[0]
# -> 2191         logpdf = self._logpdf(x, *args)
#    2192         finite_logpdf = np.isfinite(logpdf)
#    2193         n_bad += np.sum(~finite_logpdf, axis=0)
#
# ~/anaconda3/envs/StriveSchool/lib/python3.9/site-packages/scipy/stats/_distn_infrastructure.py in _logpdf(self, x, *args)
#    1795     ## Could also define any of these
#    1796     def _logpdf(self, x, *args):
# -> 1797         return log(self._pdf(x, *args))
#    1798
#    1799     def _cdf_single(self, x, *args):
#
# ~/anaconda3/envs/StriveSchool/lib/python3.9/site-packages/scipy/stats/_continuous_distns.py in _pdf(self, x, alpha, beta)
#    4637             data_subset = data_in[data_mask]
#    4638             if fft_min_points_threshold is None or len(data_subset) < fft_min_points_threshold:
# -> 4639                 data_out[data_mask] = np.array([pdf_single_value_method(_x, _alpha, _beta)
#    4640                             for _x, _alpha, _beta in data_subset]).reshape(len(data_subset), 1)
#    4641             else:
#
# ~/anaconda3/envs/StriveSchool/lib/python3.9/site-packages/scipy/stats/_continuous_distns.py in <listcomp>(.0)
#    4637             data_subset = data_in[data_mask]
#    4638             if fft_min_points_threshold is None or len(data_subset) < fft_min_points_threshold:
# -> 4639                 data_out[data_mask] = np.array([pdf_single_value_method(_x, _alpha, _beta)
#    4640                             for _x, _alpha, _beta in data_subset]).reshape(len(data_subset), 1)
#    4641             else:
#
# ~/anaconda3/envs/StriveSchool/lib/python3.9/site-packages/scipy/stats/_continuous_distns.py in _pdf_single_value_best(x, alpha, beta)
#    4486     def _pdf_single_value_best(x, alpha, beta):
#    4487         if alpha != 1. or (alpha == 1. and beta == 0.):
# -> 4488             return levy_stable_gen._pdf_single_value_zolotarev(x, alpha, beta)
#    4489         else:
#    4490             return levy_stable_gen._pdf_single_value_cf_integrate(x, alpha, beta)
#
# ~/anaconda3/envs/StriveSchool/lib/python3.9/site-packages/scipy/stats/_continuous_distns.py in _pdf_single_value_zolotarev(x, alpha, beta)
#    4528                             and intg_max.x > -xi and intg_max.x < np.pi/2:
#    4529                         intg_kwargs["points"] = [intg_max.x]
# -> 4530                     intg = integrate.quad(f, -xi, np.pi/2, **intg_kwargs)[0]
#    4531                     return alpha * intg / np.pi / np.abs(alpha-1) / (x0-zeta)
#    4532             elif x0 == zeta:
#
# ~/anaconda3/envs/StriveSchool/lib/python3.9/site-packages/scipy/integrate/quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     349
#     350     if weight is None:
# --> 351         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     352                        points)
#     353     else:
#
# ~/anaconda3/envs/StriveSchool/lib/python3.9/site-packages/scipy/integrate/quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     461     if points is None:
#     462         if infbounds == 0:
# --> 463             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     464         else:
#     465             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# ~/anaconda3/envs/StriveSchool/lib/python3.9/site-packages/scipy/stats/_continuous_distns.py in f(theta)
#    4514
#    4515                 def f(theta):
# -> 4516                     return g(theta) * np.exp(-g(theta))
#    4517
#    4518                 # spare calculating integral on null set
#
# ~/anaconda3/envs/StriveSchool/lib/python3.9/site-packages/scipy/stats/_continuous_distns.py in g(theta)
#    4510             if x0 > zeta:
#    4511                 def g(theta):
# -> 4512                     return (V(theta) *
#    4513                             np.real(np.complex128(x0-zeta)**(alpha/(alpha-1))))
#    4514
#
# ~/anaconda3/envs/StriveSchool/lib/python3.9/site-packages/scipy/stats/_continuous_distns.py in V(theta)
#    4507                 return np.cos(alpha*xi)**(1/(alpha-1)) * \
#    4508                                 (np.cos(theta)/np.sin(alpha*(xi+theta)))**(alpha/(alpha-1)) * \
# -> 4509                                 (np.cos(alpha*xi+(alpha-1)*theta)/np.cos(theta))
#    4510             if x0 > zeta:
#    4511                 def g(theta):
#
# KeyboardInterrupt:

# %% [markdown]
# ## Task 8

# %%
# box plot

df2 = df
df2['awards'].isna().any()
df3 = df2 
df3['Awards_count'] = df3.awards.str.count(',')+1
df3['Awards_count'] =df3['Awards_count'].fillna(value=0) 
#plt.boxplot(df5)

df3['Awards_count']
df3.boxplot(column=['Awards_count'])       # more awards are on 0, also more people got no awards.
df4 = df3              # having a copy
# Out:
# <AxesSubplot:>

# %%
indexNames = df3[ df3['Awards_count'] == 0 ].index
# Delete these row indexes from dataFrame
df3.drop(indexNames , inplace=True)
df3.boxplot(column=['Awards_count'])
# Out:
# <AxesSubplot:>

# %%
#plotdata.plot(kind="bar")
df6 = df5['Awards_count']
pd.Series(data=df6).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
# Delete these row indexes from dataFrame
indexNames = df3[ df3['Awards_count'] == 0 ].index
df3.drop(indexNames , inplace=True)          # deleting rows 
#df3.boxplot(column=['Awards_count'])   

df7 = df3['Awards_count']
pd.Series(data=df7).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
hist = df7.hist(bins=5)   # 4 or 5?

# %%
hist = df6.hist(bins=6)     # with 0

# %% [markdown]
# ## Task 9

# %%
df = pd.read_csv('final_01.csv')
df1 = df
max_min_value = df['avg_rating'].max() - df['avg_rating'].min()
min_value = df['avg_rating'].min()
df1['minmax_norm_ratings'] = 1 + (df1['avg_rating'] - min_value) / (max_min_value) * 9   
max_min_value = df1['avg_rating'].max() - df1['avg_rating'].min()
mean_value = df1['avg_rating'].mean()
df1['mean_norm_ratings'] = 1 + (df1['avg_rating'] - mean_value) / (max_min_value) * 9         # need to update??

df2 = df1
df2['original_publish_year'].dropna(inplace=True) 
df2['original_publish_year'].nunique()

min_1 = df2['original_publish_year'].quantile(0.01)
min_2 = df2['original_publish_year'].quantile(0.99)
df2['original_publish_year'] = np.where(df2['original_publish_year'] < min_1, min_1,df2['original_publish_year'])
df2['original_publish_year'] = np.where(df2['original_publish_year'] > min_2, min_2,df2['original_publish_year'])


ratings_per_publication_year = pd.pivot_table(data=df2, index='original_publish_year', values='minmax_norm_ratings', aggfunc=np.mean).sort_index()
ratings_per_publication_year.columns
#name_plot(1978.0)
#all_names_index = df2.set_index(['original_publish_year']).sort_index()
#all_names_index
# Out:
# Index(['minmax_norm_ratings'], dtype='object')

# %%
ratings_per_publication_year = pd.pivot_table(df2, 'minmax_norm_ratings', 'original_publish_year')
type(ratings_per_publication_year.minmax_norm_ratings)
df = ratings_per_publication_year.minmax_norm_ratings.to_frame().T  # df
#df['original_publish_year'].plot()
x = list(df)
y = np.array(df)[0]

fig = plt.figure()
ax = plt.axes()
ax.plot(x, y)

# %% [markdown]
# # Task 10
