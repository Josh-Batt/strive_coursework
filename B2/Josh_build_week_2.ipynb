# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import gzip
import tarfile

# %%
# data = b'Python - Batteries included'

# with gzip.open("raw_data.txt.gz", "wb") as f:
#     f.write(data)

# %%
# if fname.endswith("tar.gz"):
#     tar = tarfile.open(fname, "r:gz")
#     tar.extractall()
#     tar.close()
# elif fname.endswith("tar"):
#     tar = tarfile.open(fname, "r:")
#     tar.extractall()
#     tar.close()

# %%
# tar = tarfile.open("raw_data.tar.gz", "r:gz")
# for member in tar.getmembers():
#      f = tar.extractfile(member)
#      if f is not None:
#          content = f.read()

# %%
fname = "raw_data.tar.gz"

if fname.endswith("tar.gz"):
    tar = tarfile.open(fname, "r:gz")
    tar.extractall()
    tar.close()
elif fname.endswith("tar"):
    tar = tarfile.open(fname, "r:")
    tar.extractall()
    tar.close()

# %%
df_1 = pd.read_csv('raw_data/U1/sensorfile_U1_Bus_1480485018989.csv', error_bad_lines=False)
# Out:
# 377: expected 5 fields, saw 7\nSkipping line 8380: expected 5 fields, saw 7\nSkipping line 8381: expected 5 fields, saw 7\nSkipping line 8384: expected 5 fields, saw 7\nSkipping line 8385: expected 5 fields, saw 7\nSkipping line 8386: expected 5 fields, saw 7\nSkipping line 8389: expected 5 fields, saw 7\nSkipping line 8390: expected 5 fields, saw 8\nSkipping line 8391: expected 5 fields, saw 7\nSkipping line 8392: expected 5 fields, saw 6\nSkipping line 8394: expected 5 fields, saw 7\nSkipping line 8396: expected 5 fields, saw 7\nSkipping line 8399: expected 5 fields, saw 6\nSkipping line 8404: expected 5 fields, saw 8\nSkipping line 8405: expected 5 fields, saw 8\nSkipping line 8406: expected 5 fields, saw 8\nSkipping line 8409: expected 5 fields, saw 7\nSkipping line 8415: expected 5 fields, saw 7\nSkipping line 8417: expected 5 fields, saw 6\nSkipping line 8429: expected 5 fields, saw 7\nSkipping line 8433: expected 5 fields, saw 8\nSkipping line 8434: expected 5 fields, saw 7\nS
# ...

# %%
df_1
# Out:
#            2  android.sensor.accelerometer  0.5828552  6.7349396  6.423767
# 0         63  android.sensor.accelerometer   0.489548   6.811951  7.616898
# 1        111  android.sensor.accelerometer   0.238205   6.443451  7.495621
# 2        160  android.sensor.accelerometer   0.250229   6.151337  6.884811
# 3        214      android.sensor.gyroscope  -0.320679  -0.000748 -0.123337
# 4        313        android.sensor.gravity  -0.036713   6.707325  7.154078
# ...      ...                           ...        ...        ...       ...
# 6754  500146      android.sensor.gyroscope   0.519836   0.263153  0.322571
# 6755  500197  android.sensor.accelerometer   2.714600   5.303253  8.205551
# 6756  500245  android.sensor.accelerometer   2.498505   5.189758  8.573624
# 6757  500401  android.sensor.accelerometer   2.907394   5.206390  5.968475
# 6758  500534      android.sensor.gyroscope  -0.330460   0.121429  0.416641
#
# [6759 rows x 5 columns]

# %%
df_2 = pd.read_csv('raw_data/U1/sensorfile_U1_Bus_1480495444864.csv', error_bad_lines=False)
# Out:
# b'Skipping line 14: expected 7 fields, saw 8\nSkipping line 17: expected 7 fields, saw 8\nSkipping line 25: expected 7 fields, saw 8\nSkipping line 36: expected 7 fields, saw 8\nSkipping line 53: expected 7 fields, saw 8\nSkipping line 56: expected 7 fields, saw 8\nSkipping line 57: expected 7 fields, saw 8\nSkipping line 71: expected 7 fields, saw 8\nSkipping line 75: expected 7 fields, saw 8\nSkipping line 124: expected 7 fields, saw 8\nSkipping line 134: expected 7 fields, saw 8\nSkipping line 151: expected 7 fields, saw 8\nSkipping line 160: expected 7 fields, saw 8\nSkipping line 163: expected 7 fields, saw 8\nSkipping line 173: expected 7 fields, saw 8\nSkipping line 190: expected 7 fields, saw 8\nSkipping line 193: expected 7 fields, saw 8\nSkipping line 213: expected 7 fields, saw 8\nSkipping line 215: expected 7 fields, saw 8\nSkipping line 253: expected 7 fields, saw 8\nSkipping line 270: expected 7 fields, saw 8\nSkipping line 283: expected 7 fields, saw 8\nSkipping line 2
# ...

# %%
df_2
# Out:
#                                                              3  \
# 68     android.sensor.geomagnetic_rotation_vector   0.34697244
# 123    android.sensor.accelerometer                 -0.4702301
# 172    android.sensor.accelerometer                 0.10168457
# 228    android.sensor.gyroscope                     0.07511902
# 273    android.sensor.gyroscope                    -0.11180115
# ...                                                        ...
# 478042 android.sensor.gravity                      -0.39162457
# 478134 android.sensor.rotation_vector               0.34677455
# 478224 android.sensor.accelerometer                 -1.0909882
# 478313 android.sensor.game_rotation_vector          0.20601578
# 478400 android.sensor.accelerometer                 -1.4492035
#
#                                                    android.sensor.magnetic_field  \
# 68     android.sensor.geomagnetic_rotation_vector                      -0.000967
# ...

# %%
df_3 = pd.read_csv('raw_data/U1/sensorfile_U1_Bus_1480525822516.csv', error_bad_lines=False)
# Out:
# cted 5 fields, saw 6\nSkipping line 11159: expected 5 fields, saw 6\nSkipping line 11172: expected 5 fields, saw 6\nSkipping line 11177: expected 5 fields, saw 8\nSkipping line 11178: expected 5 fields, saw 8\nSkipping line 11180: expected 5 fields, saw 7\nSkipping line 11181: expected 5 fields, saw 7\nSkipping line 11186: expected 5 fields, saw 7\nSkipping line 11187: expected 5 fields, saw 6\nSkipping line 11190: expected 5 fields, saw 8\nSkipping line 11192: expected 5 fields, saw 6\nSkipping line 11193: expected 5 fields, saw 6\nSkipping line 11199: expected 5 fields, saw 8\nSkipping line 11200: expected 5 fields, saw 6\nSkipping line 11203: expected 5 fields, saw 6\nSkipping line 11204: expected 5 fields, saw 7\nSkipping line 11206: expected 5 fields, saw 8\nSkipping line 11214: expected 5 fields, saw 8\nSkipping line 11218: expected 5 fields, saw 7\nSkipping line 11219: expected 5 fields, saw 7\nSkipping line 11225: expected 5 fields, saw 8\nSkipping line 11229: expected 5 fiel
# ...

# %%
df_3
# Out:
#            2       android.sensor.magnetic_field   -22.750854  -17.596436  \
# 0         56        android.sensor.accelerometer    1.2100067    6.018326
# 1        105        android.sensor.accelerometer    1.3467255    5.927963
# 2        166        android.sensor.accelerometer     1.626236    5.777832
# 3        212       android.sensor.magnetic_field   -24.285889  -20.495605
# 4        259              android.sensor.gravity    2.0608633    6.225391
# ...      ...                                 ...          ...         ...
# 8822  641305            android.sensor.gyroscope  -0.13392639    0.042130
# 8823  641355          android.sensor.orientation    181.77356  -46.730976
# 8824  641407            android.sensor.gyroscope  0.048110962    0.004242
# 8825  641458  android.sensor.linear_acceleration   0.47805154    0.094638
# 8826  641616        android.sensor.accelerometer    1.3626404    6.746887
#
#       -48.184204
# 0       7.545288
# 1       6.880325
# 2       6.083954
# ...

# %%
df_4 = pd.read_csv('raw_data/U1/sensorfile_U1_Car_1480357774181.csv', error_bad_lines=False)
# Out:
# b'Skipping line 8: expected 5 fields, saw 7\nSkipping line 9: expected 5 fields, saw 7\nSkipping line 11: expected 5 fields, saw 18\nSkipping line 12: expected 5 fields, saw 8\nSkipping line 13: expected 5 fields, saw 6\nSkipping line 16: expected 5 fields, saw 8\nSkipping line 22: expected 5 fields, saw 7\nSkipping line 23: expected 5 fields, saw 8\nSkipping line 29: expected 5 fields, saw 7\nSkipping line 33: expected 5 fields, saw 6\nSkipping line 37: expected 5 fields, saw 8\nSkipping line 41: expected 5 fields, saw 7\nSkipping line 42: expected 5 fields, saw 6\nSkipping line 43: expected 5 fields, saw 8\nSkipping line 46: expected 5 fields, saw 8\nSkipping line 47: expected 5 fields, saw 7\nSkipping line 49: expected 5 fields, saw 6\nSkipping line 62: expected 5 fields, saw 8\nSkipping line 66: expected 5 fields, saw 7\nSkipping line 67: expected 5 fields, saw 8\nSkipping line 70: expected 5 fields, saw 18\nSkipping line 75: expected 5 fields, saw 7\nSkipping line 82: expected 5
# ...

# %%
df_4
# Out:
#          5       android.sensor.magnetic_field  -9.777832  18.862915  \
# 0       71       android.sensor.magnetic_field  -9.777832  20.909119
# 1      118              android.sensor.gravity   1.203956   6.709168
# 2      168            android.sensor.gyroscope   0.169006   0.065781
# 3     -220                               sound       -inf        NaN
# 4      271       android.sensor.magnetic_field -10.630798  20.397950
# ..     ...                                 ...        ...        ...
# 787  98022  android.sensor.linear_acceleration   0.008091  -0.030724
# 788  98096            android.sensor.gyroscope  -0.024033  -0.014862
# 789  98263              android.sensor.gravity  -2.238453   2.341680
# 790  98351            android.sensor.gyroscope  -0.025253   0.035233
# 791  98574            android.sensor.gyroscope   0.011398   0.065781
#
#      -26.646423
# 0    -25.643920
# 1      7.050386
# 2     -0.072723
# 3           NaN
# 4    -26.812744
# ..          ...
# ...
